# %%
import pandas as pd

# %%
df = pd.read_csv('Cars.csv')
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df??
# Out:
# Type:        DataFrame
# String form:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
help(df)
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame, pandas.core.arraylike.OpsMixin)
#  |  DataFrame(
#  |      data=None,
#  |      index: 'Axes | None' = None,
#  |      columns: 'Axes | None' = None,
#  |      dtype: 'Dtype | None' = None,
#  |      copy: 'bool | None' = None
#  |  ) -> 'None'
#  |
#  |  Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#  |
#  |  Data structure also contains labeled axes (rows and columns).
#  |  Arithmetic operations align on both row and column labels. Can be
#  |  thought of as a dict-like container for Series objects. The primary
#  |  pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#  |      data is a dict, column order follows insertion-order. If a dict contains Series
# ...

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib
np.__version__, pd.__version__, sns.__version__, matplotlib.__version__
# Out:
# ('2.1.3', '2.2.3', '0.13.2', '3.10.0')

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.count()
# Out:
# age         1338
# sex         1338
# bmi         1338
# children    1338
# smoker      1338
# region      1338
# charges     1338
# dtype: int64

# %%
sns.countplot(data=df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=df, x='smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.displot(data = df, x='charges')

# %%
sns.boxplot(data=df, x='sex', y='charges')
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
df['sex'].replace({'male': 0, 'female': 1}, inplace=True)
df
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    1  27.900         0    yes  southwest  16884.92400
# 1      18    0  33.770         1     no  southeast   1725.55230
# 2      28    0  33.000         3     no  southeast   4449.46200
# 3      33    0  22.705         0     no  northwest  21984.47061
# 4      32    0  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    0  30.970         3     no  northwest  10600.54830
# 1334   18    1  31.920         0     no  northeast   2205.98080
# 1335   18    1  36.850         0     no  southeast   1629.83350
# 1336   21    1  25.800         0     no  southwest   2007.94500
# 1337   61    1  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['smoker'].replace({'yes': 0, 'no': 1}, inplace=True)
df
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    1  27.900         0       0  southwest  16884.92400
# 1      18    0  33.770         1       1  southeast   1725.55230
# 2      28    0  33.000         3       1  southeast   4449.46200
# 3      33    0  22.705         0       1  northwest  21984.47061
# 4      32    0  28.880         0       1  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    0  30.970         3       1  northwest  10600.54830
# 1334   18    1  31.920         0       1  northeast   2205.98080
# 1335   18    1  36.850         0       1  southeast   1629.83350
# 1336   21    1  25.800         0       1  southwest   2007.94500
# 1337   61    1  29.070         0       0  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
plt.figure(figsize=(12, 6))
newdf = df.drop('region', axis='columns')
sns.heatmap(newdf.corr(), annot=True)
# Out:
# <Axes: >

# %%
x = df[['age','sex','bmi','children','smoker']]
y = df['charges']
x
# Out:
#       age  sex     bmi  children  smoker
# 0      19    1  27.900         0       0
# 1      18    0  33.770         1       1
# 2      28    0  33.000         3       1
# 3      33    0  22.705         0       1
# 4      32    0  28.880         0       1
# ...   ...  ...     ...       ...     ...
# 1333   50    0  30.970         3       1
# 1334   18    1  31.920         0       1
# 1335   18    1  36.850         0       1
# 1336   21    1  25.800         0       1
# 1337   61    1  29.070         0       0
#
# [1338 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

# %%
x_train[['age','sex','bmi','children','smoker']].isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# dtype: int64

# %%
# type(x_test)
x_test[['age','sex','bmi','children','smoker']].isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# dtype: int64

# %%
y_train.isna().sum()
# Out:
# np.int64(0)

# %%
y_test.isna().sum()
# Out:
# np.int64(0)

# %%
def outlier_count(col, data = x_train):
    
    # QD
    q75, q25 = np.percentile(data[col], [75, 25])
    # inter quatile
    iqr = q75 - q25
    # min_val and max_val
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    
    # outlier count
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    # outlier in percent
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    
    if(outlier_count > 0):
        print("\n"+15*'-' + col + 15*'-'+"\n")
        print('Number of outliers: {}'.format(outlier_count))
        print('Percent of data that is outlier: {}%'.format(outlier_percent))

# %%
for col in x_train.columns:
    outlier_count(col, x_train)
# Out:
# ---------------bmi---------------
#
# Number of outliers: 5
# Percent of data that is outlier: 0.62%
#
# ---------------smoker---------------
#
# Number of outliers: 168
# Percent of data that is outlier: 20.95%

# %%
x_train['smoker'].unique()
# Out:
# array([1, 0])

# %%
print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (802, 5)
# Shape of y_train: (802,)
# Shape of x_test: (536, 5)
# Shape of y_test: (536,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

lr = LinearRegression()
lr.fit(x_train, y_train)
predictData = lr.predict(x_test)

print(f"Mean Square Error is {mean_squared_error(y_test, predictData)}")
print(f"R square is {r2_score(y_test, predictData)}")
# Out:
# Mean Square Error is 35710618.68787617
# R square is 0.7605800584550678

# %%
# cross validation + grid search
from sklearn.linear_model import LinearRegression  
# we will be using linaer regression because we have less error cause R square is too close to 1.
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

algorithms = [
    LinearRegression(),
    SVR(),
    KNeighborsRegressor(),
    DecisionTreeRegressor(random_state= 0),
    RandomForestRegressor(n_estimators = 100, random_state = 0)
]

algorithmNames = [
    "Linear Regression",
    "Support Vector Regression",
    "K-Neighbors Regression",
    "Decision Tree Regression",
    "Random Forest Regression"
]

# %%
from sklearn.model_selection import KFold, cross_val_score

train_mse = []
test_mse = []

kfold = KFold(n_splits=5, shuffle=True)

for i, model in enumerate(algorithms):
    scores = cross_val_score(model, x_train, y_train, cv=kfold, scoring='neg_mean_squared_error')
    print(f"{algorithmNames[i]} - Score: {scores}; Mean: {scores.mean()}")
# Out:
# Linear Regression - Score: [-51714284.10287188 -40608702.8066622  -36152092.92722877
#  -31902217.63857027 -30598663.57593892]; Mean: -38195192.21025441
# Support Vector Regression - Score: [-1.64775432e+08 -1.29196113e+08 -1.62170620e+08 -1.42621592e+08
#  -1.99415636e+08]; Mean: -159635878.47853678
# K-Neighbors Regression - Score: [-1.37027708e+08 -1.42349518e+08 -1.36474964e+08 -1.29187816e+08
#  -1.37994114e+08]; Mean: -136606824.14742118
# Decision Tree Regression - Score: [-56222363.4580923  -42860564.18065962 -31009321.66993518
#  -47502781.77910724 -63945629.97238526]; Mean: -48308132.21203592
# Random Forest Regression - Score: [-33533375.12019303 -21621939.46574369 -25646968.52034578
#  -33582543.47224674 -25670118.19062869]; Mean: -28010988.95383159

# %%
# Using random forest because Mean score is Lowest in RandomForest
# Grid Search 

from sklearn.model_selection import GridSearchCV

param_grid = {'bootstrap': [True], 'max_depth': [5, 10, None],
              'n_estimators': [5, 6, 7, 8, 9, 10, 11, 12, 13, 15]}

rf = RandomForestRegressor(random_state = 1)

grid = GridSearchCV(estimator = rf, 
                    param_grid = param_grid, 
                    cv = kfold, 
                    n_jobs = -1, 
                    return_train_score=True, 
                    refit=True,
                    scoring='neg_mean_squared_error')

grid.fit(x_train, y_train);

# %%
grid.best_params_
# Out:
# {'bootstrap': True, 'max_depth': 5, 'n_estimators': 15}

# %%
best_mse = grid.best_score_

# %%
best_mse
# Out:
# np.float64(-22398610.340540342)

# %%
# 7. Testing 

predictData = grid.predict(x_test)
mse = mean_squared_error(y_test, predictData)
r2 = r2_score(y_test, predictData)
print(f"MSE: {mse}")
print(f"R2: {r2}")
# Out:
# MSE: 20903006.819848184
# R2: 0.8598569037780227

# %%
# grid here is randomforest
rf = grid.best_estimator_
rf.feature_importances_
# Out:
# array([0.13278987, 0.00092932, 0.18321058, 0.01189966, 0.67117056])

# %%
plt.barh(x.columns, rf.feature_importances_)
# Out:
# <BarContainer object of 5 artists>

# %%
sorted_idx = rf.feature_importances_.argsort()
plt.barh(x.columns[sorted_idx], rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
from sklearn.inspection import permutation_importance

perm_importance = permutation_importance(rf, x_test, y_test)

sorted_idx = perm_importance.importances_mean.argsort()

plt.barh(x.columns[sorted_idx], perm_importance.importances_mean[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
pip install shap
# Out:
# ...
#    ---------------------------------------- 0.0/545.1 kB ? eta -:--:--
#    ---------------------------------------- 545.1/545.1 kB 6.9 MB/s eta 0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [shap]
#    ---------------------------------------- 2/2 [shap]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import shap 

treeExplainer = shap.TreeExplainer(rf)
shapValues = treeExplainer.shap_values(x_test)

# %%
shap.summary_plot(shapValues, x_test, plot_type="bar", feature_names = x.columns)

# %%
# 9. Inference

import pickle
filename = 'model/preditMedicalCostModel.model'
pickle.dump(grid, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
df[['age','sex','bmi','children','smoker']].loc[1]
# Out:
# age         18.00
# sex          0.00
# bmi         33.77
# children     1.00
# smoker       1.00
# Name: 1, dtype: float64

# %%
sample = np.array([[18, 0, 33, 1, 1 ]])

# %%
predicted_Charge = loaded_model.predict(sample)
predicted_Charge
# Out:
# array([4491.5203732])
