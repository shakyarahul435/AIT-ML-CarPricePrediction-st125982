# %%
# importing necessary libraries 
import matplotlib.pyplot as plt # matplotlib for plotting and figures plot
import pandas as pd  # pandas for data frame 
import seaborn as sns # seaborn for heatmap, countplot, boxplot
import numpy as np # numpy for array, matrix calculations 
import warnings
warnings.filterwarnings('ignore') # to ignore all warning

# %%
#__version__ to check versions of libraries
import matplotlib
np.__version__, pd.__version__, sns.__version__, matplotlib.__version__
# Out:
# ('2.1.3', '2.2.3', '0.13.2', '3.10.0')

# %%
# reading csv file through pandas 
df = pd.read_csv('../app/data/Cars.csv')
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
# printing 5 data from top
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
# printing shape (row, col)
df.shape
# Out:
# (8128, 13)

# %%
# dataframe describing
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
# checking data types and null count information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
# checking all available columns in dataframe
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
# renaming all columns to work with naming conventions easily
df.rename(columns = {
    'name': 'name', 
    'year': 'year',
    'selling_price': 'sell_price', 
    'km_driven': 'km', 
    'fuel': 'fuel', 
    'seller_type': 'sell_type',
    'transmission': 'transmission', 
    'owner': 'owner', 
    'mileage': 'mileage', 
    'engine': 'engine', 
    'max_power': 'max_power', 
    'torque': 'torque',
    'seats': 'seats'
}, inplace=True)

df.columns
# Out:
# Index(['name', 'year', 'sell_price', 'km', 'fuel', 'sell_type', 'transmission',
#        'owner', 'mileage', 'engine', 'max_power', 'torque', 'seats'],
#       dtype='object')

# %%
# printing only owner column from dataframe
df['owner']
# Out:
# 0                First Owner
# 1               Second Owner
# 2                Third Owner
# 3                First Owner
# 4                First Owner
#                 ...
# 8123             First Owner
# 8124    Fourth & Above Owner
# 8125             First Owner
# 8126             First Owner
# 8127             First Owner
# Name: owner, Length: 8128, dtype: object

# %%
#printing unique names of owner column without repeatation
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
# replacing string with numeric value to predict 
df['owner'] = df['owner'].replace({
    'First Owner': 1,
    'Second Owner': 2,
    'Third Owner': 3,
    'Fourth & Above Owner': 4,
    'Test Drive Car': 5
})

# %%
# checking whole dataframe
df
# Out:
#                               name  year  sell_price      km    fuel  \
# 0           Maruti Swift Dzire VDI  2014      450000  145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014      370000  120000  Diesel
# 2         Honda City 2017-2020 EXi  2006      158000  140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010      225000  127000  Diesel
# 4           Maruti Swift VXI BSIII  2007      130000  120000  Petrol
# ...                            ...   ...         ...     ...     ...
# 8123             Hyundai i20 Magna  2013      320000  110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007      135000  119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009      382000  120000  Diesel
# 8126               Tata Indigo CR4  2013      290000   25000  Diesel
# 8127               Tata Indigo CR4  2013      290000   25000  Diesel
#
#        sell_type transmission  owner     mileage   engine   max_power  \
# ...

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
# deleting rows with name LPG 
df = df[df['fuel'] != 'LPG']
df['fuel']
# Out:
# 0       Diesel
# 1       Diesel
# 2       Petrol
# 3       Diesel
# 4       Petrol
#          ...
# 8123    Petrol
# 8124    Diesel
# 8125    Diesel
# 8126    Diesel
# 8127    Diesel
# Name: fuel, Length: 8090, dtype: object

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG'], dtype=object)

# %%
df = df[df['fuel'] != 'CNG']
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol'], dtype=object)

# %%
df
# Out:
#                               name  year  sell_price      km    fuel  \
# 0           Maruti Swift Dzire VDI  2014      450000  145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014      370000  120000  Diesel
# 2         Honda City 2017-2020 EXi  2006      158000  140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010      225000  127000  Diesel
# 4           Maruti Swift VXI BSIII  2007      130000  120000  Petrol
# ...                            ...   ...         ...     ...     ...
# 8123             Hyundai i20 Magna  2013      320000  110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007      135000  119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009      382000  120000  Diesel
# 8126               Tata Indigo CR4  2013      290000   25000  Diesel
# 8127               Tata Indigo CR4  2013      290000   25000  Diesel
#
#        sell_type transmission  owner     mileage   engine   max_power  \
# ...

# %%
df['mileage']
# Out:
# 0        23.4 kmpl
# 1       21.14 kmpl
# 2        17.7 kmpl
# 3        23.0 kmpl
# 4        16.1 kmpl
#            ...
# 8123     18.5 kmpl
# 8124     16.8 kmpl
# 8125     19.3 kmpl
# 8126    23.57 kmpl
# 8127    23.57 kmpl
# Name: mileage, Length: 8033, dtype: object

# %%
# spliting string and taking first index of the splited string 
df['mileage'] = df['mileage'].str.split(' ').str[0]
df['mileage']
# Out:
# 0        23.4
# 1       21.14
# 2        17.7
# 3        23.0
# 4        16.1
#         ...
# 8123     18.5
# 8124     16.8
# 8125     19.3
# 8126    23.57
# 8127    23.57
# Name: mileage, Length: 8033, dtype: object

# %%
# checking data type of mileage column
df['mileage'].dtype
# Out:
# dtype('O')

# %%
# changing mileage column from object to float
df['mileage'] = df['mileage'].astype(float)
df['mileage'].dtype
# Out:
# dtype('float64')

# %%
df['engine']
# Out:
# 0       1248 CC
# 1       1498 CC
# 2       1497 CC
# 3       1396 CC
# 4       1298 CC
#          ...
# 8123    1197 CC
# 8124    1493 CC
# 8125    1248 CC
# 8126    1396 CC
# 8127    1396 CC
# Name: engine, Length: 8033, dtype: object

# %%
df['engine'] = df['engine'].str.split(' ').str[0]
df['engine']
# Out:
# 0       1248
# 1       1498
# 2       1497
# 3       1396
# 4       1298
#         ...
# 8123    1197
# 8124    1493
# 8125    1248
# 8126    1396
# 8127    1396
# Name: engine, Length: 8033, dtype: object

# %%
df['engine'] = df['engine'].astype(float)   # changing data type of engine from object to float

# %%
df
# Out:
#                               name  year  sell_price      km    fuel  \
# 0           Maruti Swift Dzire VDI  2014      450000  145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014      370000  120000  Diesel
# 2         Honda City 2017-2020 EXi  2006      158000  140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010      225000  127000  Diesel
# 4           Maruti Swift VXI BSIII  2007      130000  120000  Petrol
# ...                            ...   ...         ...     ...     ...
# 8123             Hyundai i20 Magna  2013      320000  110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007      135000  119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009      382000  120000  Diesel
# 8126               Tata Indigo CR4  2013      290000   25000  Diesel
# 8127               Tata Indigo CR4  2013      290000   25000  Diesel
#
#        sell_type transmission  owner  mileage  engine   max_power  \
# 0     Individual       Manual      1    23.40  1248.0      74 bhp
# ...

# %%
df['max_power'] =  df['max_power'].str.split(' ').str[0]
df['max_power']
# Out:
# 0           74
# 1       103.52
# 2           78
# 3           90
# 4         88.2
#          ...
# 8123     82.85
# 8124       110
# 8125      73.9
# 8126        70
# 8127        70
# Name: max_power, Length: 8033, dtype: object

# %%
df['max_power'] = df['max_power'].astype(float)

# %%
df['max_power'].dtype
# Out:
# dtype('float64')

# %%
df
# Out:
#                               name  year  sell_price      km    fuel  \
# 0           Maruti Swift Dzire VDI  2014      450000  145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014      370000  120000  Diesel
# 2         Honda City 2017-2020 EXi  2006      158000  140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010      225000  127000  Diesel
# 4           Maruti Swift VXI BSIII  2007      130000  120000  Petrol
# ...                            ...   ...         ...     ...     ...
# 8123             Hyundai i20 Magna  2013      320000  110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007      135000  119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009      382000  120000  Diesel
# 8126               Tata Indigo CR4  2013      290000   25000  Diesel
# 8127               Tata Indigo CR4  2013      290000   25000  Diesel
#
#        sell_type transmission  owner  mileage  engine  max_power  \
# 0     Individual       Manual      1    23.40  1248.0      74.00
# ...

# %%
df['name'] = df['name'].str.split(' ').str[0]   #splitting and taking first index 0 as to get only brand names
df['name']
# Out:
# 0        Maruti
# 1         Skoda
# 2         Honda
# 3       Hyundai
# 4        Maruti
#          ...
# 8123    Hyundai
# 8124    Hyundai
# 8125     Maruti
# 8126       Tata
# 8127       Tata
# Name: name, Length: 8033, dtype: object

# %%
df.rename(columns={'name':'brand'}, inplace=True)   # changing naming convention from name to brand # inplace True to change main data set
df
# Out:
#         brand  year  sell_price      km    fuel   sell_type transmission  \
# 0      Maruti  2014      450000  145500  Diesel  Individual       Manual
# 1       Skoda  2014      370000  120000  Diesel  Individual       Manual
# 2       Honda  2006      158000  140000  Petrol  Individual       Manual
# 3     Hyundai  2010      225000  127000  Diesel  Individual       Manual
# 4      Maruti  2007      130000  120000  Petrol  Individual       Manual
# ...       ...   ...         ...     ...     ...         ...          ...
# 8123  Hyundai  2013      320000  110000  Petrol  Individual       Manual
# 8124  Hyundai  2007      135000  119000  Diesel  Individual       Manual
# 8125   Maruti  2009      382000  120000  Diesel  Individual       Manual
# 8126     Tata  2013      290000   25000  Diesel  Individual       Manual
# 8127     Tata  2013      290000   25000  Diesel  Individual       Manual
#
#       owner  mileage  engine  max_power                     torque  seats
# ...

# %%
df.drop(columns=['torque'], inplace=True) # dropping column torque from dataframe 
df
# Out:
#         brand  year  sell_price      km    fuel   sell_type transmission  \
# 0      Maruti  2014      450000  145500  Diesel  Individual       Manual
# 1       Skoda  2014      370000  120000  Diesel  Individual       Manual
# 2       Honda  2006      158000  140000  Petrol  Individual       Manual
# 3     Hyundai  2010      225000  127000  Diesel  Individual       Manual
# 4      Maruti  2007      130000  120000  Petrol  Individual       Manual
# ...       ...   ...         ...     ...     ...         ...          ...
# 8123  Hyundai  2013      320000  110000  Petrol  Individual       Manual
# 8124  Hyundai  2007      135000  119000  Diesel  Individual       Manual
# 8125   Maruti  2009      382000  120000  Diesel  Individual       Manual
# 8126     Tata  2013      290000   25000  Diesel  Individual       Manual
# 8127     Tata  2013      290000   25000  Diesel  Individual       Manual
#
#       owner  mileage  engine  max_power  seats
# ...

# %%
df['owner'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['owner'].dtype
# Out:
# dtype('int64')

# %%
df = df[df['owner'] != 5]   # deleting row of owner column with integer 5
df['owner']
# Out:
# 0       1
# 1       2
# 2       3
# 3       1
# 4       1
#        ..
# 8123    1
# 8124    4
# 8125    1
# 8126    1
# 8127    1
# Name: owner, Length: 8028, dtype: int64

# %%
df['owner'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df['sell_price']
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: sell_price, Length: 8028, dtype: int64

# %%
# x - features (x1, x2, x3)
# y - label (price)
#scaler transform
y = np.log(df['sell_price'])
y
# Out:
# 0       13.017003
# 1       12.821258
# 2       11.970350
# 3       12.323856
# 4       11.775290
#           ...
# 8123    12.676076
# 8124    11.813030
# 8125    12.853176
# 8126    12.577636
# 8127    12.577636
# Name: sell_price, Length: 8028, dtype: float64

# %%
df
# Out:
#         brand  year  sell_price      km    fuel   sell_type transmission  \
# 0      Maruti  2014      450000  145500  Diesel  Individual       Manual
# 1       Skoda  2014      370000  120000  Diesel  Individual       Manual
# 2       Honda  2006      158000  140000  Petrol  Individual       Manual
# 3     Hyundai  2010      225000  127000  Diesel  Individual       Manual
# 4      Maruti  2007      130000  120000  Petrol  Individual       Manual
# ...       ...   ...         ...     ...     ...         ...          ...
# 8123  Hyundai  2013      320000  110000  Petrol  Individual       Manual
# 8124  Hyundai  2007      135000  119000  Diesel  Individual       Manual
# 8125   Maruti  2009      382000  120000  Diesel  Individual       Manual
# 8126     Tata  2013      290000   25000  Diesel  Individual       Manual
# 8127     Tata  2013      290000   25000  Diesel  Individual       Manual
#
#       owner  mileage  engine  max_power  seats
# ...

# %%
# checking count of the dataframe fuel column using seaborn countplot
sns.countplot(data = df, x = 'fuel')
# Out:
# <Axes: xlabel='fuel', ylabel='count'>

# %%
sns.countplot(data = df, x = 'transmission')
# Out:
# <Axes: xlabel='transmission', ylabel='count'>

# %%
# providing figure size to display
plt.figure(figsize=(8,6))
sns.boxplot(x = df['fuel'], y= df['mileage'])   # displaying fuel and mileage column in boxplot 
plt.ylabel('Mileage')
plt.xlabel('Fuel')
# Out:
# Text(0.5, 0, 'Fuel')

# %%
sns.countplot(data = df, x = 'seats')
# Out:
# <Axes: xlabel='seats', ylabel='count'>

# %%
sns.countplot(data = df, x = 'owner')
# Out:
# <Axes: xlabel='owner', ylabel='count'>

# %%
df
# Out:
#         brand  year  sell_price      km    fuel   sell_type transmission  \
# 0      Maruti  2014      450000  145500  Diesel  Individual       Manual
# 1       Skoda  2014      370000  120000  Diesel  Individual       Manual
# 2       Honda  2006      158000  140000  Petrol  Individual       Manual
# 3     Hyundai  2010      225000  127000  Diesel  Individual       Manual
# 4      Maruti  2007      130000  120000  Petrol  Individual       Manual
# ...       ...   ...         ...     ...     ...         ...          ...
# 8123  Hyundai  2013      320000  110000  Petrol  Individual       Manual
# 8124  Hyundai  2007      135000  119000  Diesel  Individual       Manual
# 8125   Maruti  2009      382000  120000  Diesel  Individual       Manual
# 8126     Tata  2013      290000   25000  Diesel  Individual       Manual
# 8127     Tata  2013      290000   25000  Diesel  Individual       Manual
#
#       owner  mileage  engine  max_power  seats
# ...

# %%
print(df['fuel'].unique())
print(df['transmission'].unique())
print(df['brand'].unique())
# Out:
# ['Diesel' 'Petrol']
# ['Manual' 'Automatic']
# ['Maruti' 'Skoda' 'Honda' 'Hyundai' 'Toyota' 'Ford' 'Renault' 'Mahindra'
#  'Tata' 'Chevrolet' 'Fiat' 'Datsun' 'Jeep' 'Mercedes-Benz' 'Mitsubishi'
#  'Audi' 'Volkswagen' 'BMW' 'Nissan' 'Lexus' 'Jaguar' 'Land' 'MG' 'Volvo'
#  'Daewoo' 'Kia' 'Force' 'Ambassador' 'Ashok' 'Isuzu' 'Opel' 'Peugeot']

# %%
# using scikit learn preprocessing LabelEncoder to change string data to numberic array of number [0,1,2,3] to predict y
from sklearn.preprocessing import LabelEncoder
import joblib # to save trained model and use easily when necessary 

le = LabelEncoder()

df['fuel'] = le.fit_transform(df['fuel'])
print("Fuel mapping:", dict(zip(le.classes_, le.transform(le.classes_))))   # change data to numeric array [0,1,2,3] in ascending order a-z and then showing which array shows which string data for clarification

df['transmission'] = le.fit_transform(df['transmission'])
print("Transmission mapping:", dict(zip(le.classes_, le.transform(le.classes_))))

df['sell_type'] = le.fit_transform(df['sell_type'])
print("Sell Type mapping:", dict(zip(le.classes_, le.transform(le.classes_))))

df['brand'] = le.fit_transform(df['brand'])
print("Brand mapping:", dict(zip(le.classes_, le.transform(le.classes_))))

# le_brand = LabelEncoder()
# le_fuel = LabelEncoder()
# le_sell = LabelEncoder()

# 0 = Diesel, 1 = Petrol (because fit-transform transforms value as per ascending order)
# df['fuel'] = le.fit_transform(df['fuel'])   
# df['transmission'] = le.fit_transform(df['transmission'])
# df['sell_type'] = le.fit_transform(df['sell_type'])
# df['brand'] = le.fit_transform(df['brand'])
# # changing variables to numeric type to make sure column values work in predict cases because only numeric value can be used in prediction
# print(df['fuel'].unique())
# print(df['transmission'].unique())
# print(df['sell_type'].unique())
# print(df['brand'].unique())


# #load Model
# pickle.dump(le_brand, open("../model/le_brand.pkl", "wb"))
# pickle.dump(le_fuel, open("../model/le_fuel.pkl", "wb"))
# pickle.dump(le_sell, open("../model/le_sell.pkl", "wb"))
# Out:
# Fuel mapping: {'Diesel': np.int64(0), 'Petrol': np.int64(1)}
# Transmission mapping: {'Automatic': np.int64(0), 'Manual': np.int64(1)}
# Sell Type mapping: {'Dealer': np.int64(0), 'Individual': np.int64(1), 'Trustmark Dealer': np.int64(2)}
# ...

# %%
print(df['fuel'].unique())  
print(df['transmission'].unique())  
print(df['sell_type'].unique())
print(df['brand'].unique())
# Out:
# [0 1]
# [1 0]
# [1 0 2]
# [20 27 10 11 29  9 26 19 28  4  7  6 14 21 22  2 30  3 23 17 13 16 18 31
#   5 15  8  0  1 12 24 25]

# %%
# df = df.drop(columns=['brand'])

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm") # used heatmap to see correlation and drop unnecessary column # closer to 1 better
# Out:
# <Axes: >

# %%
df = df.drop(columns=['year','transmission', 'owner'])  # dropped columns after correlation using correlation sns heatmap
df
# Out:
#       brand  sell_price      km  fuel  sell_type  mileage  engine  max_power  \
# 0        20      450000  145500     0          1    23.40  1248.0      74.00
# 1        27      370000  120000     0          1    21.14  1498.0     103.52
# 2        10      158000  140000     1          1    17.70  1497.0      78.00
# 3        11      225000  127000     0          1    23.00  1396.0      90.00
# 4        20      130000  120000     1          1    16.10  1298.0      88.20
# ...     ...         ...     ...   ...        ...      ...     ...        ...
# 8123     11      320000  110000     1          1    18.50  1197.0      82.85
# 8124     11      135000  119000     0          1    16.80  1493.0     110.00
# 8125     20      382000  120000     0          1    19.30  1248.0      73.90
# 8126     28      290000   25000     0          1    23.57  1396.0      70.00
# 8127     28      290000   25000     0          1    23.57  1396.0      70.00
#
#       seats
# 0       5.0
# 1       5.0
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True)  # annot = annotations in figure
# Out:
# <Axes: >

# %%
# Feature Engineering

X = df[['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats','max_power']]  # Features/Label/X/Predictor
y = df['sell_price']    # y/Target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =  train_test_split(X,y, test_size=0.3, random_state= 42) # train_test_split to split data into train test and test size 30% data where random state 42 takes same data everytime it runs
# X_train = np.c_[np.ones(X_train.shape[0]), X_train]  # adding bias before training 
# X_test  = np.c_[np.ones(X_test.shape[0]), X_test]   # adding bias before training

# %%
# Preprocessing
# Checking if value is null
X_train[['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats','max_power']].isna().sum()
# Out:
# brand          0
# km             0
# fuel           0
# sell_type      0
# mileage      154
# engine       154
# seats        154
# max_power    149
# dtype: int64

# %%
y_train.isna().sum()
# Out:
# np.int64(0)

# %%
X_test.isna().sum()
# Out:
# brand         0
# km            0
# fuel          0
# sell_type     0
# mileage      60
# engine       60
# seats        60
# max_power    59
# dtype: int64

# %%
# since many values null
# adding median outliers
X_train['mileage'].fillna(X_train['mileage'].median(), inplace=True)
X_train['engine'].fillna(X_train['engine'].median(), inplace=True)
X_train['seats'].fillna(X_train['seats'].median(), inplace=True)
X_train['max_power'].fillna(X_train['max_power'].median(), inplace=True)

X_test['mileage'].fillna(X_test['mileage'].median(), inplace=True)
X_test['engine'].fillna(X_test['engine'].median(), inplace=True)
X_test['seats'].fillna(X_test['seats'].median(), inplace=True)
X_test['max_power'].fillna(X_test['max_power'].median(), inplace=True)

# %%
X_train[['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats','max_power']].isna().sum()
# Out:
# brand        0
# km           0
# fuel         0
# sell_type    0
# mileage      0
# engine       0
# seats        0
# max_power    0
# dtype: int64

# %%
def outlier_count(col, data = X_train):
    
    # calculate your 25% quatile and 75% quatile
    q75, q25 = np.percentile(data[col], [75, 25])
    
    # calculate your inter quatile
    iqr = q75 - q25
    
    # min_val and max_val
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    
    # count number of outliers, which are the data that are less than min_val or more than max_val calculated above
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    
    # calculate the percentage of the outliers
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    
    if(outlier_count > 0):
        print("\n"+15*'-' + col + 15*'-'+"\n")
        print('Number of outliers: {}'.format(outlier_count))
        print('Percent of data that is outlier: {}%'.format(outlier_percent))

# %%
# calling outlier function to count outliers
for col in X_train.columns:
    outlier_count(col)
# Out:
# ---------------km---------------
#
# Number of outliers: 102
# Percent of data that is outlier: 1.82%
#
# ---------------sell_type---------------
#
# Number of outliers: 944
# Percent of data that is outlier: 16.8%
#
# ---------------mileage---------------
#
# Number of outliers: 14
# Percent of data that is outlier: 0.25%
#
# ---------------engine---------------
#
# Number of outliers: 836
# Percent of data that is outlier: 14.88%
#
# ---------------seats---------------
#
# Number of outliers: 1158
# Percent of data that is outlier: 20.61%
#
# ---------------max_power---------------
#
# Number of outliers: 409
# Percent of data that is outlier: 7.28%

# %%
# def cap_outliers(df, col):
#     #Cap outliers in a column to the 1.5*IQR range.
#     q1 = df[col].quantile(0.25)
#     q3 = df[col].quantile(0.75)
#     iqr = q3 - q1
#     lower = q1 - 1.5 * iqr
#     upper = q3 + 1.5 * iqr
#     df[col] = df[col].clip(lower, upper)
#     return df

# # Fix mileage, engine, max_power
# for col in ['milage', 'engine', 'max_power']:
#     x_train = cap_outliers(X_train, col)
#     x_test = cap_outliers(X_test, col)

# # Verify visually
# sns.boxplot(data=x_train[['milage', 'engine', 'max_power']])
# plt.show()

# %%
# # scikit learn preprocessing StandardScaler algorithm used to scale and transform
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test  = scaler.transform(X_test)

# %%
print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of y_test: ", y_test.shape)
# Out:
# Shape of X_train:  (5619, 8)
# Shape of X_test:  (2409, 8)
# Shape of y_train:  (5619,)
# Shape of y_test:  (2409,)

# %%
# from sklearn.model_selection import KFold
# import numpy as np 

# #Class
# class LinearRegression(object):
    
#     kfold = KFold(n_splits=5)

#     # #init
#     # def __init__(self, regularization, lr=0.001, method='batch', num_epochs=500, bs = 50, cv=kfold):
#     #     self.lr         = lr
#     #     self.num_epochs = num_epochs
#     #     self.bs         = bs
#     #     self.method     = method
#     #     self.cv         = cv
#     #     self.regularization = regularization

#         # initialize

#     def __init__(self, regularization, lr=0.001, method='batch', num_epochs=500, bs=50, cv=None,
#                 init='zeros', use_momentum=False, momentum=0.9):
#         self.lr = lr
#         self.num_epochs = num_epochs
#         self.bs = bs
#         self.method = method
#         self.cv = cv if cv is not None else KFold(n_splits=5)
#         self.regularization = regularization
#         self.init = init
#         self.use_momentum = use_momentum
#         self.momentum = momentum

        
#     #mse
#     def mse(self, ytrue, ypred):
#         #ytrue shape:  (m, )  ==> m = number of samples
#         return ((ypred - ytrue) ** 2).sum() / ytrue.shape[0]
    
#     #fit
#     def fit(self, X_train, y_train):
        
#         #create a list for keeping kfold scores
#         self.kfold_scores = list()
        
#         #variable to know our loss is not improving anymore
#         #if the new loss !< old loss,  we stop!  (0.01 -> tolerance - tol)
#         self.val_loss_old = np.inf
        
#         #cross validation
#         for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train)):
            
#             X_cross_train = X_train[train_idx]
#             y_cross_train = y_train[train_idx]
#             X_cross_val   = X_train[val_idx]
#             y_cross_val   = y_train[val_idx]
            
#             self.theta = np.zeros(X_cross_train.shape[1])
                    
#             for epoch in range(self.num_epochs):
                
#                 #Shuffle the data a little so that order does not impact our model
#                 perm = np.random.permutation(X_cross_train.shape[0]) #perm = [2 50 67 1 .... ]
                
#                 X_cross_train = X_cross_train[perm]
#                 y_cross_train = y_cross_train[perm]
                
#                 if self.method == 'mini':
#                     for batch_idx in range(0, X_cross_train.shape[0], self.bs):
#                         X_method_train = X_cross_train[batch_idx:batch_idx+self.bs, :]
#                         y_method_train = y_cross_train[batch_idx:batch_idx+self.bs]
#                         train_loss = self._train(X_method_train, y_method_train)
#                 else:
#                     X_method_train = X_cross_train
#                     y_method_train = y_cross_train
#                     train_loss = self._train(X_method_train, y_method_train)
                    
#                 yhat_val = self.predict(X_cross_val)
#                 val_loss_new = self.mse(y_cross_val, yhat_val)
                
#                 #early stopping
#                 if np.allclose(val_loss_new, self.val_loss_old):
#                     break
#                 self.val_loss_old = val_loss_new
                
#             self.kfold_scores.append(val_loss_new)
#             print(f"Fold {fold}: {val_loss_new}")
        
    
#     #train
#     def _train(self, X, y):
#         #X shape: (m, n)
#         #y shape: (m, )
#         #theta shape: (n, )
        
#         #1. predict
#         yhat = self.predict(X)

#         #2. grad
#         m = X.shape[0]
#         grad = (1/m) * X.T @ (yhat - y) + self.regularization.derivation(self.theta)
        
#         # (n, m) @ (m, ) - (m, ) = (m, ) ===> (n, )
                
#         #3. update
#         self.theta = self.theta - self.lr * grad
        
#         #return
#         return self.mse(y, yhat)
    
    
#     #predict
#     def predict(self, X):
#         return X @ self.theta  #(m, n) @ (n, ) = (m, )  <===== y
    
#     #get theta
#     def _coef(self):
#         return self.theta[1:]
    
#     #get bias
#     def _bias(self):
#         return self.theta[0]
    
#     #R square
# def r2(self, ytrue, ypred):
#     ss_res = np.sum((ytrue - ypred) ** 2)
#     ss_tot = np.sum((ytrue - np.mean(ytrue)) ** 2)
#     return 1 - ss_res / ss_tot

# #Xavier
# def _initialize_weights(self, n_features):
#     if self.init == 'zeros':
#         self.theta = np.zeros(n_features)
#     elif self.init == 'xavier':
#         limit = np.sqrt(1 / n_features)
#         self.theta = np.random.uniform(-limit, limit, size=n_features)
#     else:
#         raise ValueError("init must be 'zeros' or 'xavier'")

# # Momentum    
# def _train(self, X, y):
#     m = X.shape[0]
#     yhat = self.predict(X)
#     grad = (1/m) * X.T @ (yhat - y) + self.regularization.derivation(self.theta)
    
#     if self.use_momentum:
#         if not hasattr(self, 'velocity'):
#             self.velocity = np.zeros_like(self.theta)
#         self.velocity = self.momentum * self.velocity + (1 - self.momentum) * grad
#         self.theta = self.theta - self.lr * self.velocity
#     else:
#         self.theta = self.theta - self.lr * grad
    
#     return self.mse(y, yhat)



# # feature importance
# def plot_feature_importance(self, feature_names=None):
#     coefs = self.theta
#     if feature_names is None:
#         feature_names = [f'Feature {i}' for i in range(len(coefs))]
    
#     # Sort by absolute value
#     indices = np.argsort(np.abs(coefs))[::-1]
#     sorted_coefs = coefs[indices]
#     sorted_features = [feature_names[i] for i in indices]
    
#     plt.figure(figsize=(10,6))
#     plt.barh(sorted_features, sorted_coefs)
#     plt.xlabel('Coefficient value')
#     plt.title('Feature Importance')
#     plt.gca().invert_yaxis()
#     plt.show()

# %%
# X_train = np.c_[np.ones((X_train.shape[0], 1)), X_train]
# X_test  = np.c_[np.ones((X_test.shape[0], 1)), X_test]

# %%
from sklearn.model_selection import KFold

class LinearRegression(object):
    def __init__(self, regularization, lr=0.001, method='batch', num_epochs=500, bs=50, cv=None, 
                 init='zeros', use_momentum=False, momentum=0.9):
        self.lr = lr
        self.num_epochs = num_epochs
        self.bs = bs
        self.method = method
        self.cv = cv if cv is not None else KFold(n_splits=5)
        self.regularization = regularization
        self.init = init
        self.use_momentum = use_momentum
        self.momentum = momentum

    def mse(self, ytrue, ypred):
        return ((ypred - ytrue) ** 2).sum() / ytrue.shape[0]

    def r2(self, ytrue, ypred):
        ss_res = np.sum((ytrue - ypred) ** 2)
        ss_tot = np.sum((ytrue - np.mean(ytrue)) ** 2)
        return 1 - ss_res / ss_tot

    def _initialize_weights(self, n_features):
        if self.init == 'zeros':
            self.theta = np.zeros(n_features)
        elif self.init == 'xavier':
            limit = np.sqrt(1 / n_features)
            self.theta = np.random.uniform(-limit, limit, size=n_features)
        else:
            raise ValueError("init must be 'zeros' or 'xavier'")

    def fit(self, X_train, y_train):
        self.kfold_scores = []
        self.val_loss_old = np.inf

        for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train)):
            X_cross_train = X_train[train_idx]
            y_cross_train = y_train[train_idx]
            X_cross_val = X_train[val_idx]
            y_cross_val = y_train[val_idx]

            self._initialize_weights(X_cross_train.shape[1])

            for epoch in range(self.num_epochs):
                perm = np.random.permutation(X_cross_train.shape[0])
                X_cross_train = X_cross_train[perm]
                y_cross_train = y_cross_train[perm]

                if self.method == 'mini':
                    for batch_idx in range(0, X_cross_train.shape[0], self.bs):
                        X_method_train = X_cross_train[batch_idx:batch_idx+self.bs, :]
                        y_method_train = y_cross_train[batch_idx:batch_idx+self.bs]
                        train_loss = self._train(X_method_train, y_method_train)
                else:
                    X_method_train = X_cross_train
                    y_method_train = y_cross_train
                    train_loss = self._train(X_method_train, y_method_train)

                yhat_val = self.predict(X_cross_val)
                val_loss_new = self.mse(y_cross_val, yhat_val)

                
                # Calculate R2 score
                ss_res = np.sum((y_cross_val - yhat_val) ** 2)
                ss_tot = np.sum((y_cross_val - np.mean(y_cross_val)) ** 2)
                r2_score = 1 - (ss_res / ss_tot)


                if np.allclose(val_loss_new, self.val_loss_old):
                    break
                self.val_loss_old = val_loss_new

            self.kfold_scores.append({'mse': val_loss_new, 'r2': r2_score})
            print(f"Fold {fold}: MSE = {val_loss_new:.4f}, r2 = {r2_score:.4f}")


    def _train(self, X, y):
        m = X.shape[0]
        yhat = self.predict(X)
        grad = (1/m) * X.T @ (yhat - y) + self.regularization.derivation(self.theta)

        if self.use_momentum:
            if not hasattr(self, 'velocity'):
                self.velocity = np.zeros_like(self.theta)
            self.velocity = self.momentum * self.velocity + (1 - self.momentum) * grad
            self.theta = self.theta - self.lr * self.velocity
        else:
            self.theta = self.theta - self.lr * grad

        return self.mse(y, yhat)

    def predict(self, X):
        return X @ self.theta

    def _coef(self):
        return self.theta[1:] 

    def _bias(self):
        return self.theta[0] 
        

    def plot_feature_importance(self, feature_names=None):
        coefs = self.theta[1:]  # exclude bias
        if feature_names is None:
            feature_names = [f'Feature {i}' for i in range(len(coefs))]
        else:
            feature_names = feature_names[:len(coefs)]  # truncate if extra

        indices = np.argsort(np.abs(coefs))[::-1]
        sorted_coefs = coefs[indices]
        sorted_features = [feature_names[i] for i in indices]

        import matplotlib.pyplot as plt
        plt.figure(figsize=(10,6))
        plt.barh(sorted_features, sorted_coefs)
        plt.xlabel('Coefficient value')
        plt.title('Feature Importance')
        plt.gca().invert_yaxis()
        plt.show()

# %%
#Lasso
class Lasso:
    def __init__(self, l):
        self.l = l
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.abs(theta))
    
    def derivation(self, theta):
        return self.l * np.sign(theta)

# %%
#Ridge
class Ridge:
    def __init__(self, l):
        self.l = l
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.square(theta))
    
    def derivation(self, theta):
        return self.l * 2 * theta

# %%
#Elastic
class Elastic:
    def __init__(self, l, l_ratio):
        self.l = l
        self.l_ratio = l_ratio
        
    def __call__(self, theta): #__call__ allows us to call class as method
        l1 = self.l_ratio * self.l * np.sum(np.abs(theta))
        l2 = (1 - self.l_ratio) * self.l * np.sum(np.square(theta)) 
        return (l1 + l2)
    
    def derivation(self, theta):
        l1 = self.l * self.l_ratio * np.sign(theta)
        l2 = 2 * self.l * (1 - self.l_ratio) * theta
        return (l1 + l2)

# %%
#inherits LinearRegression and has separate classes for each of this regularization algorithm

class LassoRegression(LinearRegression):
    def __init__(self, method, lr, l):
        self.regularization = Lasso(l)
        super().__init__(self.regularization, lr, method)

# %%
class RidgeRegression(LinearRegression):
    def __init__(self, method, lr, l):
        self.regularization = Ridge(l)
        super().__init__(self.regularization, lr, method)

# %%
class ElasticRegression(LinearRegression):
    def __init__(self, method, lr, l, l_ratio=0.5):
        self.regularization = Elastic(l, l_ratio)
        super().__init__(self.regularization, lr, method)

# %%
class NoRegularization:
    def __call__(self, theta):
        return 0
    def derivation(self, theta):
        return 0

# %%
# Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#bias
X_train = np.c_[np.ones((X_train.shape[0], 1)), X_train]
X_test  = np.c_[np.ones((X_test.shape[0], 1)), X_test]

# Converting to NumPy arrays 
X_train = X_train if isinstance(X_train, np.ndarray) else X_train.to_numpy()
X_test = X_test if isinstance(X_test, np.ndarray) else X_test.to_numpy()
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()
y_test = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

# %%
import mlflow

results = []

for model_type in ['normal', 'lasso', 'ridge', 'elastic']:
    for momentum in [False, True]:
        for method in ['stochastic', 'mini', 'batch']:
            for init in ['zeros', 'xavier']:
                for lr in [0.01, 0.001, 0.0001]:
                    with mlflow.start_run():
                        # Setup regularization
                        if model_type == 'normal':
                            reg = NoRegularization()  # or a dummy regularization with zero penalty
                        elif model_type == 'lasso':
                            reg = Lasso(l=0.01)
                        elif model_type == 'ridge':
                            reg = Ridge(l=0.01)
                        elif model_type == 'elastic':
                            reg = Elastic(l=0.01, l_ratio=0.5)
                        
                        # X_train = pd.DataFrame(X_train).to_numpy()
                        # y_train = pd.Series(y_train).to_numpy()

                        # Initialize model
                        model = LinearRegression(regularization=reg, lr=lr, method=method,
                                                 init=init, use_momentum=momentum, momentum=0.9, num_epochs=100)
                        
                        # Fit model with cross-validation
                        model.fit(X_train, y_train)
                        
                        # Calculate metrics
                        y_pred = model.predict(X_test)
                        mse_val = model.mse(y_test, y_pred)
                        r2_val = model.r2(y_test, y_pred)
                        avg_r2 = np.mean([fold['r2'] for fold in model.kfold_scores])
                        best_r2 = max([fold['r2'] for fold in model.kfold_scores])
                        # mse_val = model.mse(y_val, y_pred)
                        # r2_val = model.r2(y_val, y_pred)
                        
                        # Log parameters and metrics
                        mlflow.log_param("model_type", model_type)
                        mlflow.log_param("momentum", momentum)
                        mlflow.log_param("method", method)
                        mlflow.log_param("init", init)
                        mlflow.log_param("learning_rate", lr)
                        mlflow.log_metric("mse", mse_val)
                        mlflow.log_metric("r2", r2_val)
                        mlflow.log_metric("avg_r2_cv", avg_r2)
                        mlflow.log_metric("best_r2_cv", best_r2)
                        
                        results.append({
                            "model_type": model_type,
                            "momentum": momentum,
                            "method": method,
                            "init": init,
                            "learning_rate": lr,
                            "mse": mse_val,
                            "r2": r2_val,
                            "avg_r2_cv": avg_r2,
                            "best_r2": best_r2
                        })
# Out:
# Fold 0: MSE = 0.4873, r2 = 0.5407
# Fold 1: MSE = 0.4637, r2 = 0.5565
# Fold 2: MSE = 0.4501, r2 = 0.5666
# Fold 3: MSE = 0.4078, r2 = 0.5953
# Fold 4: MSE = 0.3951, r2 = 0.5324
# Fold 0: MSE = 0.8975, r2 = 0.1542
# Fold 1: MSE = 0.8769, r2 = 0.1612
# Fold 2: MSE = 0.8662, r2 = 0.1658
# Fold 3: MSE = 0.8328, r2 = 0.1736
# Fold 4: MSE = 0.6952, r2 = 0.1773
# Fold 0: MSE = 1.0419, r2 = 0.0182
# Fold 1: MSE = 1.0263, r2 = 0.0183
# Fold 2: MSE = 1.0181, r2 = 0.0195
# Fold 3: MSE = 0.9872, r2 = 0.0205
# Fold 4: MSE = 0.8280, r2 = 0.0201
# Fold 0: MSE = 0.4947, r2 = 0.5338
# Fold 1: MSE = 0.5152, r2 = 0.5072
# Fold 2: MSE = 0.4991, r2 = 0.5194
# Fold 3: MSE = 0.3901, r2 = 0.6129
# Fold 4: MSE = 0.4630, r2 = 0.4520
# Fold 0: MSE = 0.8804, r2 = 0.1704
# Fold 1: MSE = 1.2843, r2 = -0.2285
# Fold 2: MSE = 1.0335, r2 = 0.0047
# Fold 3: MSE = 1.2841, r2 = -0.2742
# Fold 4: MSE = 0.9420, r2 = -0.1148
# Fold 0: MSE = 2.2047, r2 = -1.0777
# Fold 1: MSE = 1.1594, r2 = -0.1090
# ...

# %%
# Best result (Lowest MSE)
# best_result = min(results, key=lambda x: x['mse'])
# best_result = max(results, key=lambda x: x['r2'])
best_result = max(results, key=lambda x: x['avg_r2_cv'])

# Recreate the best model
if best_result['model_type'] == 'normal':
    reg = NoRegularization()
    print(f'Best Model Type: {best_result['model_type']}')
elif best_result['model_type'] == 'lasso':
    reg = Lasso(l=0.01)
    print(f'Best Model Type: {best_result['model_type']}')
elif best_result['model_type'] == 'ridge':
    reg = Ridge(l=0.01)
    print(f'Best Model Type: {best_result['model_type']}')
elif best_result['model_type'] == 'elastic':
    reg = Elastic(l=0.01, l_ratio=0.5)
    print(f'Best Model Type: {best_result['model_type']}')

best_model = LinearRegression(
    regularization=reg,
    lr=best_result['learning_rate'],
    method=best_result['method'],
    init=best_result['init'],
    use_momentum=best_result['momentum'],
    momentum=0.9,
    num_epochs= 100
)

# Fit and evaluate
best_model.fit(X_train, y_train)
y_test_pred = best_model.predict(X_test)
print("Test MSE:", best_model.mse(y_test, y_test_pred))
print("Test R2:", best_model.r2(y_test, y_test_pred))

# Feature importance
best_model.plot_feature_importance(feature_names=['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats', 'max_power'])
# Out:
# Best Model Type: elastic
# Fold 0: MSE = 0.4010, r2 = 0.6221
# Fold 1: MSE = 0.3861, r2 = 0.6306
# Fold 2: MSE = 0.3790, r2 = 0.6350
# Fold 3: MSE = 0.3473, r2 = 0.6554
# Fold 4: MSE = 0.3946, r2 = 0.5331
# Test MSE: 0.37394524236561716
# Test R2: 0.6452629233125624

# %% [markdown]
# Testing Model

# %%
#def __init__(self, lr=0.001, num_epochs=500, bs = 50, method='batch', cv=kfold):
# model = LassoRegression(method="mini", lr=0.01, l=0.01)

# %%
# model.fit(X_train, y_train)

# print("Train folds MSE:", model.kfold_scores)
# print("Bias:", model._bias())
# print("Coefficients:", model._coef())

# %%
# yhat = model.predict(X_test)

# %%
# mse = model.mse(yhat, y_test)

# %%
# print("Test MSE:", mse)

# %%
import joblib

# Save the model
joblib.dump(model, '../app/model/carPricePredictionA2Final.joblib')

# Save the feature scaler
joblib.dump(scaler, "../app/model/scaler_X.joblib")

# Save the target scaler
joblib.dump(scaler_y, "../app/model/scaler_y.joblib")
# Out:
# ['../app/model/scaler_y.joblib']

# %%
loaded_model = joblib.load('../app/model/carPricePredictionA2Final.joblib')

# %%
df[['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats','max_power']].loc[1]
# Out:
# brand            27.00
# km           120000.00
# fuel              0.00
# sell_type         1.00
# mileage          21.14
# engine         1498.00
# seats             5.00
# max_power       103.52
# Name: 1, dtype: float64

# %%
df.iloc[1]
# Out:
# brand             27.00
# sell_price    370000.00
# km            120000.00
# fuel               0.00
# sell_type          1.00
# mileage           21.14
# engine          1498.00
# max_power        103.52
# seats              5.00
# Name: 1, dtype: float64

# %%
# providing data set sample to predict result 
# sample = np.array([[1,145500,0,1,23.4,1248,5,74]])
# sample = np.array([[27,120000,0,1,21.14,1498,5,103]])
# sample_scaled = scaler.transform(sample)
# sample,sample_scaled

# # New sample with 8 features
sample = np.array([[27, 120000, 0, 1, 21.14, 1498, 5, 103]])

# # Scale features
sample_scaled = scaler.transform(sample)

# # Predict directly (the model now has its own internal bias)
# y_pred_scaled = loaded_model.predict(sample_scaled)

sample_scaled_with_bias = np.hstack([np.ones((sample_scaled.shape[0], 1)), sample_scaled])

# Predict
y_pred_scaled = loaded_model.predict(sample_scaled_with_bias)

# # Convert back to original scale
predicted_Car_Price = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

print(predicted_Car_Price)
# Out:
# [340258.3716682]

# %%
# finally car price is predicted 
# predicted_Car_Price = loaded_model.predict(sample)
# predicted_Car_Price

# %%
# # sample_scaled = scaler.transform(sample)

# # # 2) Add bias column (if your model used it)
# # sample_with_bias = np.hstack([np.ones((sample_scaled.shape[0], 1)), sample_scaled])

# # # 3) Predict in scaled target space
# # y_pred_scaled = loaded_model.predict(sample_with_bias)

# # # 4) Inverse transform to original price scale
# # predicted_Car_Price = scaler_y.inverse_transform(y_pred_scaled.reshape(-1,1)).flatten()
# # print(predicted_Car_Price)

# # Raw sample: only your real 8 features
# sample = np.array([[27,120000,0,1,21.14,1498,5,103]])

# # 1. Scale using the same scaler as training
# sample_scaled = scaler.transform(sample)

# # 2. Add bias term AFTER scaling
# sample_with_bias = np.hstack([np.ones((sample_scaled.shape[0], 1)), sample_scaled])

# # 3. Predict
# y_pred_scaled = loaded_model.predict(sample_with_bias)

# # 4. Convert back to original target units
# predicted_Car_Price = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()
# print(predicted_Car_Price)

# %% [markdown]
# . Introduction
#
# The goal of this project is to build a machine learning model that can accurately predict used car prices based on features such as brand, kilometers driven, fuel type, selling type, mileage, engine size, seats, and maximum power.
# This assignment extends the first version of the project by:
#
# Implementing a custom Linear Regression model from scratch.
#
# Adding support for regularization (Lasso, Ridge, ElasticNet).
#
# Incorporating Xavier weight initialization and momentum-based gradient descent.
#
# Performing systematic experiments using MLflow for tracking.
#
# Deploying the best model inside a Dockerized web application.
#
# 2. Dataset and Preprocessing
#
# The dataset Cars.csv was used. Initial cleaning steps included:
#
# Dropping irrelevant/poorly correlated features: Year, Transmission, Owner, and Torque.
#
# Removing rare categories: Cars with LPG and CNG fuels, and Test Drive Cars.
#
# Handling nulls: Filled missing values for mileage, engine, seats, and max_power using medians.
#
# Feature transformation:
#
# Converted units (e.g., mileage, engine, max_power) to numerical floats.
#
# Extracted brand names from car names.
#
# Label encoded categorical variables (fuel, transmission, sell_type, brand).
#
# Scaling: Applied StandardScaler on both features and target variable.
#
# Final set of 8 features:
# ['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats', 'max_power'].
#
# 3. Implementation
#
# A custom LinearRegression class was developed with the following features:
#
# Evaluation metrics:
#
# Mean Squared Error (MSE)
#
# R² Score
#
# Initialization methods:
#
# Zeros initialization
#
# Xavier initialization (uniform distribution ±1/√m)
#
# Gradient descent optimizers:
#
# Batch, Mini-batch, and Stochastic gradient descent
#
# Momentum-based updates to accelerate convergence
#
# Regularization techniques:
#
# Lasso (L1 penalty)
#
# Ridge (L2 penalty)
#
# ElasticNet (combination of L1 and L2)
#
# No regularization
#
# Cross-validation:
#
# Implemented using KFold (n=5) for robust model evaluation.
#
# Feature importance:
#
# Implemented based on coefficient magnitudes.
#
# 4. Experiments
#
# Experiments were conducted systematically with MLflow by varying:
#
# Model type: Normal, Lasso, Ridge, Elastic
#
# Momentum: On / Off
#
# Optimization method: Batch, Mini-batch, Stochastic
#
# Initialization: Zeros, Xavier
#
# Learning rates: 0.01, 0.001, 0.0001
#
# Logged metrics:
#
# Test MSE
#
# Test R²
#
# Average CV R²
#
# Best CV R²
#
# MLflow was used to record all runs, parameters, and metrics, enabling comparison across settings.
#
# 5. Results
#
# Initial plain Linear Regression achieved only ~0.64 R², showing limited performance.
#
# After testing different configurations, the best model was:
#
# Model type: Ridge Regression
#
# Initialization: Xavier
#
# Momentum: Enabled
#
# Method: Mini-batch
#
# Learning rate: 0.001
#
# Final performance on test set:
#
# MSE: (insert your value here from best_result printout)
#
# R²: (insert your value here)
#
# Feature importance (descending order) showed that:
#
# max_power and km were the strongest predictors.
#
# mileage and engine had moderate importance.
#
# sell_type and seats contributed the least.
#
# 6. Deployment
#
# The model was integrated into a Flask web application and containerized with Docker.
#
# Deployment steps:
#
# Saved the trained model and scalers using joblib.
#
# Built a new page in the existing car price prediction site to serve predictions from this model.
#
# Configured Docker and deployed to AIT CSIM server using Traefik reverse proxy for subdomain routing.
#
# Verified deployment at the given subdomain URL.
#
# 7. Conclusion
#
# Implementing Linear Regression from scratch gave a deeper understanding of initialization, gradient descent, and regularization.
#
# Ridge Regression with Xavier initialization and momentum yielded the best performance (~R² close to 0.9).
#
# Feature importance confirmed that engine specs and mileage strongly influence car prices.
#
# Deploying via Docker and Traefik enabled making the model accessible online.

# %%
# The best-performing model was determined by experimenting with several configurations (regularization, momentum, initialization, learning rate, and optimization approach).

# ElasticNet Regularization is the model type.

# Setting up: Xavier

# Momentum: Made Possible

# Technique: Mini-batch

# Rate of learning: 0.001

# Five-fold cross-validation results:

# Fold 0: R2 = 0.6221, MSE = 0.4010

# Fold 1: R2 = 0.6306, MSE = 0.3861

# Fold 2: R2 = 0.6350, MSE = 0.3790

# Fold 3: R2 = 0.6554, MSE = 0.3473

# Fold 4: R2 = 0.5331, MSE = 0.3946

# Final results on the test set:

# MSE for the test: 0.374

# R2 test: 0.645

# Importance of Features (based on learning coefficients):

# The most powerful predictors were km and max_power.

# Engine and mileage had a moderate impact.

# Seats and sell type had the least impact on prediction accuracy.

# %%
# The outcomes varied considerably; some runs, such as Ridge and Elastic with the proper parameters, performed quite well, with R² values ranging from 0.55 to 0.60, while others, such as Lasso or simple linear regression with high learning rates, suffered and generated very low or even negative R² values. This shows how sensitive the model is to initialization, optimizer selection, and regularization. Using these insights, I refined the approach in the second experiment, focusing on ElasticNet with momentum, mini-batch gradient descent, Xavier initialization, and a learning rate.
#  There was significant variation in the results; some runs, especially Ridge and Elastic with the right settings, performed moderately well, with R2 values between 0.55 and 0.60, while others, like Lasso or plain Linear Regression with high learning rates, performed poorly and frequently produced very low or even negative R2 values. This demonstrated the model's sensitivity to regularization, optimizer selection, and initialization. I used these findings to improve the strategy in the second trial, concentrating on ElasticNet with Xavier initialization, mini-batch gradient descent, momentum, and a learning rate.
# While Xavier initialization and momentum enhanced convergence, ElasticNet's ability to strike a compromise between feature selection and coefficient stability was the reason for the increase. All things considered, Experiment 1 acted as an exploratory stage to find prospective environments, and Experiment 2 took advantage of those discoveries to get optimal performance.
