# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment(experiment_name="a2")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/190877290999588017', creation_time=1757530875663, experiment_id='190877290999588017', last_update_time=1757530875663, lifecycle_stage='active', name='a2', tags={}>

# %%
# importing necessary libraries 
import matplotlib.pyplot as plt # matplotlib for plotting and figures plot
import pandas as pd  # pandas for data frame 
import seaborn as sns # seaborn for heatmap, countplot, boxplot
import numpy as np # numpy for array, matrix calculations 
import warnings
warnings.filterwarnings('ignore') # to ignore all warning

# %%
#__version__ to check versions of libraries
import matplotlib
np.__version__, pd.__version__, sns.__version__, matplotlib.__version__
# Out:
# ('2.1.3', '2.2.3', '0.13.2', '3.10.0')

# %%
# reading csv file through pandas 
df = pd.read_csv('../app/data/Cars.csv')
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]

# %%
# printing 5 data from top
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
# printing shape (row, col)
df.shape
# Out:
# (8128, 13)

# %%
# dataframe describing
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
# checking data types and null count information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
# checking all available columns in dataframe
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
# renaming all columns to work with naming conventions easily
df.rename(columns = {
    'name': 'name', 
    'year': 'year',
    'selling_price': 'sell_price', 
    'km_driven': 'km', 
    'fuel': 'fuel', 
    'seller_type': 'sell_type',
    'transmission': 'transmission', 
    'owner': 'owner', 
    'mileage': 'mileage', 
    'engine': 'engine', 
    'max_power': 'max_power', 
    'torque': 'torque',
    'seats': 'seats'
}, inplace=True)

df.columns
# Out:
# Index(['name', 'year', 'sell_price', 'km', 'fuel', 'sell_type', 'transmission',
#        'owner', 'mileage', 'engine', 'max_power', 'torque', 'seats'],
#       dtype='object')

# %%
# printing only owner column from dataframe
df['owner']
# Out:
# 0                First Owner
# 1               Second Owner
# 2                Third Owner
# 3                First Owner
# 4                First Owner
#                 ...
# 8123             First Owner
# 8124    Fourth & Above Owner
# 8125             First Owner
# 8126             First Owner
# 8127             First Owner
# Name: owner, Length: 8128, dtype: object

# %%
#printing unique names of owner column without repeatation
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
# replacing string with numeric value to predict 
df['owner'] = df['owner'].replace({
    'First Owner': 1,
    'Second Owner': 2,
    'Third Owner': 3,
    'Fourth & Above Owner': 4,
    'Test Drive Car': 5
})

# %%
# checking whole dataframe
df
# Out:
#                               name  year  sell_price      km    fuel  \
# 0           Maruti Swift Dzire VDI  2014      450000  145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014      370000  120000  Diesel
# 2         Honda City 2017-2020 EXi  2006      158000  140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010      225000  127000  Diesel
# 4           Maruti Swift VXI BSIII  2007      130000  120000  Petrol
# ...                            ...   ...         ...     ...     ...
# 8123             Hyundai i20 Magna  2013      320000  110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007      135000  119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009      382000  120000  Diesel
# 8126               Tata Indigo CR4  2013      290000   25000  Diesel
# 8127               Tata Indigo CR4  2013      290000   25000  Diesel
#
#        sell_type transmission  owner     mileage   engine   max_power  \
# 0     Individual       Manual      1   23.4 kmpl  1248 CC      74 bhp
# 1     Individual       Manual      2  21.14 kmpl  1498 CC  103.52 bhp
# 2     Individual       Manual      3   17.7 kmpl  1497 CC      78 bhp
# 3     Individual       Manual      1   23.0 kmpl  1396 CC      90 bhp
# 4     Individual       Manual      1   16.1 kmpl  1298 CC    88.2 bhp
# ...          ...          ...    ...         ...      ...         ...
# 8123  Individual       Manual      1   18.5 kmpl  1197 CC   82.85 bhp
# 8124  Individual       Manual      4   16.8 kmpl  1493 CC     110 bhp
# 8125  Individual       Manual      1   19.3 kmpl  1248 CC    73.9 bhp
# 8126  Individual       Manual      1  23.57 kmpl  1396 CC      70 bhp
# 8127  Individual       Manual      1  23.57 kmpl  1396 CC      70 bhp
#
#                          torque  seats
# 0                190Nm@ 2000rpm    5.0
# 1           250Nm@ 1500-2500rpm    5.0
# 2         12.7@ 2,700(kgm@ rpm)    5.0
# 3      22.4 kgm at 1750-2750rpm    5.0
# 4         11.5@ 4,500(kgm@ rpm)    5.0
# ...                         ...    ...
# 8123           113.7Nm@ 4000rpm    5.0
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125             190Nm@ 2000rpm    5.0
# 8126        140Nm@ 1800-3000rpm    5.0
# 8127        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
# deleting rows with name LPG 
df = df[df['fuel'] != 'LPG']
df['fuel']
# Out:
# 0       Diesel
# 1       Diesel
# 2       Petrol
# 3       Diesel
# 4       Petrol
#          ...
# 8123    Petrol
# 8124    Diesel
# 8125    Diesel
# 8126    Diesel
# 8127    Diesel
# Name: fuel, Length: 8090, dtype: object

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG'], dtype=object)

# %%
df = df[df['fuel'] != 'CNG']
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol'], dtype=object)

# %%
df
# Out:
#                               name  year  sell_price      km    fuel  \
# 0           Maruti Swift Dzire VDI  2014      450000  145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014      370000  120000  Diesel
# 2         Honda City 2017-2020 EXi  2006      158000  140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010      225000  127000  Diesel
# 4           Maruti Swift VXI BSIII  2007      130000  120000  Petrol
# ...                            ...   ...         ...     ...     ...
# 8123             Hyundai i20 Magna  2013      320000  110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007      135000  119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009      382000  120000  Diesel
# 8126               Tata Indigo CR4  2013      290000   25000  Diesel
# 8127               Tata Indigo CR4  2013      290000   25000  Diesel
#
#        sell_type transmission  owner     mileage   engine   max_power  \
# 0     Individual       Manual      1   23.4 kmpl  1248 CC      74 bhp
# 1     Individual       Manual      2  21.14 kmpl  1498 CC  103.52 bhp
# 2     Individual       Manual      3   17.7 kmpl  1497 CC      78 bhp
# 3     Individual       Manual      1   23.0 kmpl  1396 CC      90 bhp
# 4     Individual       Manual      1   16.1 kmpl  1298 CC    88.2 bhp
# ...          ...          ...    ...         ...      ...         ...
# 8123  Individual       Manual      1   18.5 kmpl  1197 CC   82.85 bhp
# 8124  Individual       Manual      4   16.8 kmpl  1493 CC     110 bhp
# 8125  Individual       Manual      1   19.3 kmpl  1248 CC    73.9 bhp
# 8126  Individual       Manual      1  23.57 kmpl  1396 CC      70 bhp
# 8127  Individual       Manual      1  23.57 kmpl  1396 CC      70 bhp
#
#                          torque  seats
# 0                190Nm@ 2000rpm    5.0
# 1           250Nm@ 1500-2500rpm    5.0
# 2         12.7@ 2,700(kgm@ rpm)    5.0
# 3      22.4 kgm at 1750-2750rpm    5.0
# 4         11.5@ 4,500(kgm@ rpm)    5.0
# ...                         ...    ...
# 8123           113.7Nm@ 4000rpm    5.0
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125             190Nm@ 2000rpm    5.0
# 8126        140Nm@ 1800-3000rpm    5.0
# 8127        140Nm@ 1800-3000rpm    5.0
#
# [8033 rows x 13 columns]

# %%
df['mileage']
# Out:
# 0        23.4 kmpl
# 1       21.14 kmpl
# 2        17.7 kmpl
# 3        23.0 kmpl
# 4        16.1 kmpl
#            ...
# 8123     18.5 kmpl
# 8124     16.8 kmpl
# 8125     19.3 kmpl
# 8126    23.57 kmpl
# 8127    23.57 kmpl
# Name: mileage, Length: 8033, dtype: object

# %%
# spliting string and taking first index of the splited string 
df['mileage'] = df['mileage'].str.split(' ').str[0]
df['mileage']
# Out:
# 0        23.4
# 1       21.14
# 2        17.7
# 3        23.0
# 4        16.1
#         ...
# 8123     18.5
# 8124     16.8
# 8125     19.3
# 8126    23.57
# 8127    23.57
# Name: mileage, Length: 8033, dtype: object

# %%
# checking data type of mileage column
df['mileage'].dtype
# Out:
# dtype('O')

# %%
# changing mileage column from object to float
df['mileage'] = df['mileage'].astype(float)
df['mileage'].dtype
# Out:
# dtype('float64')

# %%
df['engine']
# Out:
# 0       1248 CC
# 1       1498 CC
# 2       1497 CC
# 3       1396 CC
# 4       1298 CC
#          ...
# 8123    1197 CC
# 8124    1493 CC
# 8125    1248 CC
# 8126    1396 CC
# 8127    1396 CC
# Name: engine, Length: 8033, dtype: object

# %%
df['engine'] = df['engine'].str.split(' ').str[0]
df['engine']
# Out:
# 0       1248
# 1       1498
# 2       1497
# 3       1396
# 4       1298
#         ...
# 8123    1197
# 8124    1493
# 8125    1248
# 8126    1396
# 8127    1396
# Name: engine, Length: 8033, dtype: object

# %%
df['engine'] = df['engine'].astype(float)   # changing data type of engine from object to float

# %%
df
# Out:
#                               name  year  sell_price      km    fuel  \
# 0           Maruti Swift Dzire VDI  2014      450000  145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014      370000  120000  Diesel
# 2         Honda City 2017-2020 EXi  2006      158000  140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010      225000  127000  Diesel
# 4           Maruti Swift VXI BSIII  2007      130000  120000  Petrol
# ...                            ...   ...         ...     ...     ...
# 8123             Hyundai i20 Magna  2013      320000  110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007      135000  119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009      382000  120000  Diesel
# 8126               Tata Indigo CR4  2013      290000   25000  Diesel
# 8127               Tata Indigo CR4  2013      290000   25000  Diesel
#
#        sell_type transmission  owner  mileage  engine   max_power  \
# 0     Individual       Manual      1    23.40  1248.0      74 bhp
# 1     Individual       Manual      2    21.14  1498.0  103.52 bhp
# 2     Individual       Manual      3    17.70  1497.0      78 bhp
# 3     Individual       Manual      1    23.00  1396.0      90 bhp
# 4     Individual       Manual      1    16.10  1298.0    88.2 bhp
# ...          ...          ...    ...      ...     ...         ...
# 8123  Individual       Manual      1    18.50  1197.0   82.85 bhp
# 8124  Individual       Manual      4    16.80  1493.0     110 bhp
# 8125  Individual       Manual      1    19.30  1248.0    73.9 bhp
# 8126  Individual       Manual      1    23.57  1396.0      70 bhp
# 8127  Individual       Manual      1    23.57  1396.0      70 bhp
#
#                          torque  seats
# 0                190Nm@ 2000rpm    5.0
# 1           250Nm@ 1500-2500rpm    5.0
# 2         12.7@ 2,700(kgm@ rpm)    5.0
# 3      22.4 kgm at 1750-2750rpm    5.0
# 4         11.5@ 4,500(kgm@ rpm)    5.0
# ...                         ...    ...
# 8123           113.7Nm@ 4000rpm    5.0
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125             190Nm@ 2000rpm    5.0
# 8126        140Nm@ 1800-3000rpm    5.0
# 8127        140Nm@ 1800-3000rpm    5.0
#
# [8033 rows x 13 columns]

# %%
df['max_power'] =  df['max_power'].str.split(' ').str[0]
df['max_power']
# Out:
# 0           74
# 1       103.52
# 2           78
# 3           90
# 4         88.2
#          ...
# 8123     82.85
# 8124       110
# 8125      73.9
# 8126        70
# 8127        70
# Name: max_power, Length: 8033, dtype: object

# %%
df['max_power'] = df['max_power'].astype(float)

# %%
df['max_power'].dtype
# Out:
# dtype('float64')

# %%
df
# Out:
#                               name  year  sell_price      km    fuel  \
# 0           Maruti Swift Dzire VDI  2014      450000  145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014      370000  120000  Diesel
# 2         Honda City 2017-2020 EXi  2006      158000  140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010      225000  127000  Diesel
# 4           Maruti Swift VXI BSIII  2007      130000  120000  Petrol
# ...                            ...   ...         ...     ...     ...
# 8123             Hyundai i20 Magna  2013      320000  110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007      135000  119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009      382000  120000  Diesel
# 8126               Tata Indigo CR4  2013      290000   25000  Diesel
# 8127               Tata Indigo CR4  2013      290000   25000  Diesel
#
#        sell_type transmission  owner  mileage  engine  max_power  \
# 0     Individual       Manual      1    23.40  1248.0      74.00
# 1     Individual       Manual      2    21.14  1498.0     103.52
# 2     Individual       Manual      3    17.70  1497.0      78.00
# 3     Individual       Manual      1    23.00  1396.0      90.00
# 4     Individual       Manual      1    16.10  1298.0      88.20
# ...          ...          ...    ...      ...     ...        ...
# 8123  Individual       Manual      1    18.50  1197.0      82.85
# 8124  Individual       Manual      4    16.80  1493.0     110.00
# 8125  Individual       Manual      1    19.30  1248.0      73.90
# 8126  Individual       Manual      1    23.57  1396.0      70.00
# 8127  Individual       Manual      1    23.57  1396.0      70.00
#
#                          torque  seats
# 0                190Nm@ 2000rpm    5.0
# 1           250Nm@ 1500-2500rpm    5.0
# 2         12.7@ 2,700(kgm@ rpm)    5.0
# 3      22.4 kgm at 1750-2750rpm    5.0
# 4         11.5@ 4,500(kgm@ rpm)    5.0
# ...                         ...    ...
# 8123           113.7Nm@ 4000rpm    5.0
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125             190Nm@ 2000rpm    5.0
# 8126        140Nm@ 1800-3000rpm    5.0
# 8127        140Nm@ 1800-3000rpm    5.0
#
# [8033 rows x 13 columns]

# %%
df['name'] = df['name'].str.split(' ').str[0]   #splitting and taking first index 0 as to get only brand names
df['name']
# Out:
# 0        Maruti
# 1         Skoda
# 2         Honda
# 3       Hyundai
# 4        Maruti
#          ...
# 8123    Hyundai
# 8124    Hyundai
# 8125     Maruti
# 8126       Tata
# 8127       Tata
# Name: name, Length: 8033, dtype: object

# %%
df.rename(columns={'name':'brand'}, inplace=True)   # changing naming convention from name to brand # inplace True to change main data set
df
# Out:
#         brand  year  sell_price      km    fuel   sell_type transmission  \
# 0      Maruti  2014      450000  145500  Diesel  Individual       Manual
# 1       Skoda  2014      370000  120000  Diesel  Individual       Manual
# 2       Honda  2006      158000  140000  Petrol  Individual       Manual
# 3     Hyundai  2010      225000  127000  Diesel  Individual       Manual
# 4      Maruti  2007      130000  120000  Petrol  Individual       Manual
# ...       ...   ...         ...     ...     ...         ...          ...
# 8123  Hyundai  2013      320000  110000  Petrol  Individual       Manual
# 8124  Hyundai  2007      135000  119000  Diesel  Individual       Manual
# 8125   Maruti  2009      382000  120000  Diesel  Individual       Manual
# 8126     Tata  2013      290000   25000  Diesel  Individual       Manual
# 8127     Tata  2013      290000   25000  Diesel  Individual       Manual
#
#       owner  mileage  engine  max_power                     torque  seats
# 0         1    23.40  1248.0      74.00             190Nm@ 2000rpm    5.0
# 1         2    21.14  1498.0     103.52        250Nm@ 1500-2500rpm    5.0
# 2         3    17.70  1497.0      78.00      12.7@ 2,700(kgm@ rpm)    5.0
# 3         1    23.00  1396.0      90.00   22.4 kgm at 1750-2750rpm    5.0
# 4         1    16.10  1298.0      88.20      11.5@ 4,500(kgm@ rpm)    5.0
# ...     ...      ...     ...        ...                        ...    ...
# 8123      1    18.50  1197.0      82.85           113.7Nm@ 4000rpm    5.0
# 8124      4    16.80  1493.0     110.00  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125      1    19.30  1248.0      73.90             190Nm@ 2000rpm    5.0
# 8126      1    23.57  1396.0      70.00        140Nm@ 1800-3000rpm    5.0
# 8127      1    23.57  1396.0      70.00        140Nm@ 1800-3000rpm    5.0
#
# [8033 rows x 13 columns]

# %%
df.drop(columns=['torque'], inplace=True) # dropping column torque from dataframe 
df
# Out:
#         brand  year  sell_price      km    fuel   sell_type transmission  \
# 0      Maruti  2014      450000  145500  Diesel  Individual       Manual
# 1       Skoda  2014      370000  120000  Diesel  Individual       Manual
# 2       Honda  2006      158000  140000  Petrol  Individual       Manual
# 3     Hyundai  2010      225000  127000  Diesel  Individual       Manual
# 4      Maruti  2007      130000  120000  Petrol  Individual       Manual
# ...       ...   ...         ...     ...     ...         ...          ...
# 8123  Hyundai  2013      320000  110000  Petrol  Individual       Manual
# 8124  Hyundai  2007      135000  119000  Diesel  Individual       Manual
# 8125   Maruti  2009      382000  120000  Diesel  Individual       Manual
# 8126     Tata  2013      290000   25000  Diesel  Individual       Manual
# 8127     Tata  2013      290000   25000  Diesel  Individual       Manual
#
#       owner  mileage  engine  max_power  seats
# 0         1    23.40  1248.0      74.00    5.0
# 1         2    21.14  1498.0     103.52    5.0
# 2         3    17.70  1497.0      78.00    5.0
# 3         1    23.00  1396.0      90.00    5.0
# 4         1    16.10  1298.0      88.20    5.0
# ...     ...      ...     ...        ...    ...
# 8123      1    18.50  1197.0      82.85    5.0
# 8124      4    16.80  1493.0     110.00    5.0
# 8125      1    19.30  1248.0      73.90    5.0
# 8126      1    23.57  1396.0      70.00    5.0
# 8127      1    23.57  1396.0      70.00    5.0
#
# [8033 rows x 12 columns]

# %%
df['owner'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['owner'].dtype
# Out:
# dtype('int64')

# %%
df = df[df['owner'] != 5]   # deleting row of owner column with integer 5
df['owner']
# Out:
# 0       1
# 1       2
# 2       3
# 3       1
# 4       1
#        ..
# 8123    1
# 8124    4
# 8125    1
# 8126    1
# 8127    1
# Name: owner, Length: 8028, dtype: int64

# %%
df['owner'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df['sell_price']
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: sell_price, Length: 8028, dtype: int64

# %%
# x - features (x1, x2, x3)
# y - label (price)
#scaler transform
y = np.log(df['sell_price'])
y
# Out:
# 0       13.017003
# 1       12.821258
# 2       11.970350
# 3       12.323856
# 4       11.775290
#           ...
# 8123    12.676076
# 8124    11.813030
# 8125    12.853176
# 8126    12.577636
# 8127    12.577636
# Name: sell_price, Length: 8028, dtype: float64

# %%
df
# Out:
#         brand  year  sell_price      km    fuel   sell_type transmission  \
# 0      Maruti  2014      450000  145500  Diesel  Individual       Manual
# 1       Skoda  2014      370000  120000  Diesel  Individual       Manual
# 2       Honda  2006      158000  140000  Petrol  Individual       Manual
# 3     Hyundai  2010      225000  127000  Diesel  Individual       Manual
# 4      Maruti  2007      130000  120000  Petrol  Individual       Manual
# ...       ...   ...         ...     ...     ...         ...          ...
# 8123  Hyundai  2013      320000  110000  Petrol  Individual       Manual
# 8124  Hyundai  2007      135000  119000  Diesel  Individual       Manual
# 8125   Maruti  2009      382000  120000  Diesel  Individual       Manual
# 8126     Tata  2013      290000   25000  Diesel  Individual       Manual
# 8127     Tata  2013      290000   25000  Diesel  Individual       Manual
#
#       owner  mileage  engine  max_power  seats
# 0         1    23.40  1248.0      74.00    5.0
# 1         2    21.14  1498.0     103.52    5.0
# 2         3    17.70  1497.0      78.00    5.0
# 3         1    23.00  1396.0      90.00    5.0
# 4         1    16.10  1298.0      88.20    5.0
# ...     ...      ...     ...        ...    ...
# 8123      1    18.50  1197.0      82.85    5.0
# 8124      4    16.80  1493.0     110.00    5.0
# 8125      1    19.30  1248.0      73.90    5.0
# 8126      1    23.57  1396.0      70.00    5.0
# 8127      1    23.57  1396.0      70.00    5.0
#
# [8028 rows x 12 columns]

# %%
# checking count of the dataframe fuel column using seaborn countplot
sns.countplot(data = df, x = 'fuel')
# Out:
# <Axes: xlabel='fuel', ylabel='count'>

# %%
sns.countplot(data = df, x = 'transmission')
# Out:
# <Axes: xlabel='transmission', ylabel='count'>

# %%
# providing figure size to display
plt.figure(figsize=(8,6))
sns.boxplot(x = df['fuel'], y= df['mileage'])   # displaying fuel and mileage column in boxplot 
plt.ylabel('Mileage')
plt.xlabel('Fuel')
# Out:
# Text(0.5, 0, 'Fuel')

# %%
sns.countplot(data = df, x = 'seats')
# Out:
# <Axes: xlabel='seats', ylabel='count'>

# %%
sns.countplot(data = df, x = 'owner')
# Out:
# <Axes: xlabel='owner', ylabel='count'>

# %%
df
# Out:
#         brand  year  sell_price      km    fuel   sell_type transmission  \
# 0      Maruti  2014      450000  145500  Diesel  Individual       Manual
# 1       Skoda  2014      370000  120000  Diesel  Individual       Manual
# 2       Honda  2006      158000  140000  Petrol  Individual       Manual
# 3     Hyundai  2010      225000  127000  Diesel  Individual       Manual
# 4      Maruti  2007      130000  120000  Petrol  Individual       Manual
# ...       ...   ...         ...     ...     ...         ...          ...
# 8123  Hyundai  2013      320000  110000  Petrol  Individual       Manual
# 8124  Hyundai  2007      135000  119000  Diesel  Individual       Manual
# 8125   Maruti  2009      382000  120000  Diesel  Individual       Manual
# 8126     Tata  2013      290000   25000  Diesel  Individual       Manual
# 8127     Tata  2013      290000   25000  Diesel  Individual       Manual
#
#       owner  mileage  engine  max_power  seats
# 0         1    23.40  1248.0      74.00    5.0
# 1         2    21.14  1498.0     103.52    5.0
# 2         3    17.70  1497.0      78.00    5.0
# 3         1    23.00  1396.0      90.00    5.0
# 4         1    16.10  1298.0      88.20    5.0
# ...     ...      ...     ...        ...    ...
# 8123      1    18.50  1197.0      82.85    5.0
# 8124      4    16.80  1493.0     110.00    5.0
# 8125      1    19.30  1248.0      73.90    5.0
# 8126      1    23.57  1396.0      70.00    5.0
# 8127      1    23.57  1396.0      70.00    5.0
#
# [8028 rows x 12 columns]

# %%
print(df['fuel'].unique())
print(df['transmission'].unique())
print(df['brand'].unique())
# Out:
# ['Diesel' 'Petrol']
# ['Manual' 'Automatic']
# ['Maruti' 'Skoda' 'Honda' 'Hyundai' 'Toyota' 'Ford' 'Renault' 'Mahindra'
#  'Tata' 'Chevrolet' 'Fiat' 'Datsun' 'Jeep' 'Mercedes-Benz' 'Mitsubishi'
#  'Audi' 'Volkswagen' 'BMW' 'Nissan' 'Lexus' 'Jaguar' 'Land' 'MG' 'Volvo'
#  'Daewoo' 'Kia' 'Force' 'Ambassador' 'Ashok' 'Isuzu' 'Opel' 'Peugeot']

# %%
# using scikit learn preprocessing LabelEncoder to change string data to numberic array of number [0,1,2,3] to predict y
from sklearn.preprocessing import LabelEncoder
import pickle # import pickle to save trained model and use easily when necessary 

le = LabelEncoder()

df['fuel'] = le.fit_transform(df['fuel'])
print("Fuel mapping:", dict(zip(le.classes_, le.transform(le.classes_))))   # change data to numeric array [0,1,2,3] in ascending order a-z and then showing which array shows which string data for clarification

df['transmission'] = le.fit_transform(df['transmission'])
print("Transmission mapping:", dict(zip(le.classes_, le.transform(le.classes_))))

df['sell_type'] = le.fit_transform(df['sell_type'])
print("Sell Type mapping:", dict(zip(le.classes_, le.transform(le.classes_))))

df['brand'] = le.fit_transform(df['brand'])
print("Brand mapping:", dict(zip(le.classes_, le.transform(le.classes_))))

# le_brand = LabelEncoder()
# le_fuel = LabelEncoder()
# le_sell = LabelEncoder()

# 0 = Diesel, 1 = Petrol (because fit-transform transforms value as per ascending order)
# df['fuel'] = le.fit_transform(df['fuel'])   
# df['transmission'] = le.fit_transform(df['transmission'])
# df['sell_type'] = le.fit_transform(df['sell_type'])
# df['brand'] = le.fit_transform(df['brand'])
# # changing variables to numeric type to make sure column values work in predict cases because only numeric value can be used in prediction
# print(df['fuel'].unique())
# print(df['transmission'].unique())
# print(df['sell_type'].unique())
# print(df['brand'].unique())


# #load Model
# pickle.dump(le_brand, open("../model/le_brand.pkl", "wb"))
# pickle.dump(le_fuel, open("../model/le_fuel.pkl", "wb"))
# pickle.dump(le_sell, open("../model/le_sell.pkl", "wb"))
# Out:
# Fuel mapping: {'Diesel': np.int64(0), 'Petrol': np.int64(1)}
# Transmission mapping: {'Automatic': np.int64(0), 'Manual': np.int64(1)}
# Sell Type mapping: {'Dealer': np.int64(0), 'Individual': np.int64(1), 'Trustmark Dealer': np.int64(2)}
# Brand mapping: {'Ambassador': np.int64(0), 'Ashok': np.int64(1), 'Audi': np.int64(2), 'BMW': np.int64(3), 'Chevrolet': np.int64(4), 'Daewoo': np.int64(5), 'Datsun': np.int64(6), 'Fiat': np.int64(7), 'Force': np.int64(8), 'Ford': np.int64(9), 'Honda': np.int64(10), 'Hyundai': np.int64(11), 'Isuzu': np.int64(12), 'Jaguar': np.int64(13), 'Jeep': np.int64(14), 'Kia': np.int64(15), 'Land': np.int64(16), 'Lexus': np.int64(17), 'MG': np.int64(18), 'Mahindra': np.int64(19), 'Maruti': np.int64(20), 'Mercedes-Benz': np.int64(21), 'Mitsubishi': np.int64(22), 'Nissan': np.int64(23), 'Opel': np.int64(24), 'Peugeot': np.int64(25), 'Renault': np.int64(26), 'Skoda': np.int64(27), 'Tata': np.int64(28), 'Toyota': np.int64(29), 'Volkswagen': np.int64(30), 'Volvo': np.int64(31)}

# %%
print(df['fuel'].unique())  
print(df['transmission'].unique())  
print(df['sell_type'].unique())
print(df['brand'].unique())
# Out:
# [0 1]
# [1 0]
# [1 0 2]
# [20 27 10 11 29  9 26 19 28  4  7  6 14 21 22  2 30  3 23 17 13 16 18 31
#   5 15  8  0  1 12 24 25]

# %%
# df = df.drop(columns=['brand'])

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm") # used heatmap to see correlation and drop unnecessary column # closer to 1 better
# Out:
# <Axes: >

# %%
df = df.drop(columns=['year','transmission', 'owner'])  # dropped columns after correlation using correlation sns heatmap
df
# Out:
#       brand  sell_price      km  fuel  sell_type  mileage  engine  max_power  \
# 0        20      450000  145500     0          1    23.40  1248.0      74.00
# 1        27      370000  120000     0          1    21.14  1498.0     103.52
# 2        10      158000  140000     1          1    17.70  1497.0      78.00
# 3        11      225000  127000     0          1    23.00  1396.0      90.00
# 4        20      130000  120000     1          1    16.10  1298.0      88.20
# ...     ...         ...     ...   ...        ...      ...     ...        ...
# 8123     11      320000  110000     1          1    18.50  1197.0      82.85
# 8124     11      135000  119000     0          1    16.80  1493.0     110.00
# 8125     20      382000  120000     0          1    19.30  1248.0      73.90
# 8126     28      290000   25000     0          1    23.57  1396.0      70.00
# 8127     28      290000   25000     0          1    23.57  1396.0      70.00
#
#       seats
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
# ...     ...
# 8123    5.0
# 8124    5.0
# 8125    5.0
# 8126    5.0
# 8127    5.0
#
# [8028 rows x 9 columns]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True)  # annot = annotations in figure
# Out:
# <Axes: >

# %%
# Feature Engineering

X = df[['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats','max_power']]  # Features/Label/X/Predictor
y = df['sell_price']    # y/Target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =  train_test_split(X,y, test_size=0.3, random_state= 42) # train_test_split to split data into train test and test size 30% data where random state 42 takes same data everytime it runs

# %%
# Preprocessing
# Checking if value is null
X_train[['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats','max_power']].isna().sum()
# Out:
# brand          0
# km             0
# fuel           0
# sell_type      0
# mileage      154
# engine       154
# seats        154
# max_power    149
# dtype: int64

# %%
y_train.isna().sum()
# Out:
# np.int64(0)

# %%
X_test.isna().sum()
# Out:
# brand         0
# km            0
# fuel          0
# sell_type     0
# mileage      60
# engine       60
# seats        60
# max_power    59
# dtype: int64

# %%
# since many values null
# adding median outliers
X_train['mileage'].fillna(X_train['mileage'].median(), inplace=True)
X_train['engine'].fillna(X_train['engine'].median(), inplace=True)
X_train['seats'].fillna(X_train['seats'].median(), inplace=True)
X_train['max_power'].fillna(X_train['max_power'].median(), inplace=True)

X_test['mileage'].fillna(X_test['mileage'].median(), inplace=True)
X_test['engine'].fillna(X_test['engine'].median(), inplace=True)
X_test['seats'].fillna(X_test['seats'].median(), inplace=True)
X_test['max_power'].fillna(X_test['max_power'].median(), inplace=True)

# %%
X_train[['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats','max_power']].isna().sum()
# Out:
# brand        0
# km           0
# fuel         0
# sell_type    0
# mileage      0
# engine       0
# seats        0
# max_power    0
# dtype: int64

# %%
def outlier_count(col, data = X_train):
    
    # calculate your 25% quatile and 75% quatile
    q75, q25 = np.percentile(data[col], [75, 25])
    
    # calculate your inter quatile
    iqr = q75 - q25
    
    # min_val and max_val
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    
    # count number of outliers, which are the data that are less than min_val or more than max_val calculated above
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    
    # calculate the percentage of the outliers
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    
    if(outlier_count > 0):
        print("\n"+15*'-' + col + 15*'-'+"\n")
        print('Number of outliers: {}'.format(outlier_count))
        print('Percent of data that is outlier: {}%'.format(outlier_percent))

# %%
# calling outlier function to count outliers
for col in X_train.columns:
    outlier_count(col)
# Out:
# ---------------km---------------
#
# Number of outliers: 102
# Percent of data that is outlier: 1.82%
#
# ---------------sell_type---------------
#
# Number of outliers: 944
# Percent of data that is outlier: 16.8%
#
# ---------------mileage---------------
#
# Number of outliers: 14
# Percent of data that is outlier: 0.25%
#
# ---------------engine---------------
#
# Number of outliers: 836
# Percent of data that is outlier: 14.88%
#
# ---------------seats---------------
#
# Number of outliers: 1158
# Percent of data that is outlier: 20.61%
#
# ---------------max_power---------------
#
# Number of outliers: 409
# Percent of data that is outlier: 7.28%

# %%
# scikit learn preprocessing StandardScaler algorithm used to scale and transform
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of y_test: ", y_test.shape)
# Out:
# Shape of X_train:  (5619, 8)
# Shape of X_test:  (2409, 8)
# Shape of y_train:  (5619,)
# Shape of y_test:  (2409,)

# %%
# from sklearn.linear_model import LinearRegression   # using linear regression algorithm to test model 
# from sklearn.metrics import mean_squared_error, r2_score 
#  # using mean square error and r2 score to check error where MSE can be any number so causes issue finding error , using R square to predict closest to 1 best

# lr = LinearRegression()
# lr.fit(X_train, y_train)
# yPred = lr.predict(X_test)

# print("MSE: ", mean_squared_error(y_test, yPred))
# print("r2: ", r2_score(y_test, yPred))

# %%
# !pip install mlflow

# %%
# # Modeling LinearRegression
# from sklearn.model_selection import KFold
# import mlflow

# #Class
# class LinearRegression(object):
    
#     kfold = KFold(n_splits=5)
    
#     #init
#     # def __init__(self, regularization, lr=0.001, init='xavier', method='batch', num_epochs=500, bs = 50, cv=kfold, poly=True, degree=2, use_momentum):
#     def __init__(self, 
#                  regularization, 
#                  lr = 0.001, 
#                  init = 'xavier', #.i.e. zero 
#                  method = 'batch', 
#                  poly = True, 
#                  degree = 2,
#                  use_momentum = True, 
#                  momentum = 0.5, 
#                  bs = 50,
#                  num_epochs = 500,
#                  cv=KFold):
        
#         self.lr         = lr
#         self.num_epochs = num_epochs
#         self.bs         = bs
#         self.method     = method
#         self.cv         = cv
#         self.regularization = regularization
#         self.init = init
#         self.poly = poly # boolean to check polynomial
#         self.degree = degree
#         self.use_momentum = use_momentum
#         self.momentum = momentum
#         self.vel  = None
#         self.poly_transformer = None
#         self.feature_names  = None
        
#     #mse
#     def mse(self, ytrue, ypred):
#         #ytrue shape:  (m, )  ==> m = number of samples
#         return ((ypred - ytrue) ** 2).sum() / ytrue.shape[0]
    
#     def r2(self, ytrue, ypred):
#         ss_res = ((ytrue - ypred) ** 2).sum()
#         ss_tot = ((ytrue - ytrue.mean()) ** 2).sum()
#         return 1 - (ss_res / ss_tot) if ss_tot != 0 else 0.0
    
#     def xavier_init(self, n_features):
#         limit = np.sqrt(6.0 / (n_features + 1))     # Initializing weights using Xavier 
#         return np.random.uniform(-limit, limit, size=n_features)
    
#     def _init_weights(self, n_features):
#         if self.init == "xavier":
#             return self.xavier_init(n_features)
#         elif self.init == "zero":
#             return np.zeros(n_features)
#         else:
#             raise ValueError("init must be 'zero' or 'xavier'")
    
#     #fit
#     # def fit(self, X_train, y_train):
        
#     #     #create a list for keeping kfold scores
#     #     self.kfold_scores = list()
        
#     #     #variable to know our loss is not improving anymore
#     #     #if the new loss !< old loss,  we stop!  (0.01 -> tolerance - tol)
#     #     self.val_loss_old = np.infty
        
#     #     #cross validation
#     #     for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train)):
            
#     #         X_cross_train = X_train[train_idx]
#     #         y_cross_train = y_train[train_idx]
#     #         X_cross_val   = X_train[val_idx]
#     #         y_cross_val   = y_train[val_idx]
            
#     #         self.theta = np.zeros(X_cross_train.shape[1])
                    
#     #         for epoch in range(self.num_epochs):
                
#     #             #Shuffle the data a little so that order does not impact our model
#     #             perm = np.random.permutation(X_cross_train.shape[0]) #perm = [2 50 67 1 .... ]
                
#     #             X_cross_train = X_cross_train[perm]
#     #             y_cross_train = y_cross_train[perm]
                
#     #             if self.method == 'mini':
#     #                 for batch_idx in range(0, X_cross_train.shape[0], self.bs):
#     #                     X_method_train = X_cross_train[batch_idx:batch_idx+self.bs, :]
#     #                     y_method_train = y_cross_train[batch_idx:batch_idx+self.bs]
#     #                     train_loss = self._train(X_method_train, y_method_train)
#     #             else:
#     #                 X_method_train = X_cross_train
#     #                 y_method_train = y_cross_train
#     #                 train_loss = self._train(X_method_train, y_method_train)
                    
#     #             yhat_val = self.predict(X_cross_val)
#     #             val_loss_new = self.mse(y_cross_val, yhat_val)
                
#     #             #early stopping
#     #             if np.allclose(val_loss_new, self.val_loss_old):
#     #                 break
#     #             self.val_loss_old = val_loss_new
                
#     #         self.kfold_scores.append(val_loss_new)
#     #         print(f"Fold {fold}: {val_loss_new}")
        
    
#     def fit(self, X_train, y_train):        # The main function to train the model on your data
        
#         self.kfold_scores = []
#         self.kfold_r2 = []
#         self.val_loss_old = np.inf

#         if isinstance(X_train, pd.DataFrame):
#             self.feature_names = X_train.columns.tolist()
#             X_train = X_train.values
#         else:
#             self.feature_names = [f"feature_{i}" for i in range(X_train.shape[1])]
            
#         if isinstance(y_train, pd.Series):
#             y_train = y_train.values
#         if self.polynomial and self.poly_transformer is None:                   # We prepare the polynomial features on the entire dataset first, which is more efficient
#             self.poly_transformer = PolynomialFeatures(degree=self.degree, include_bias=False)
#             X_train_poly = self.poly_transformer.fit_transform(X_train)
#         elif self.polynomial:
#             X_train_poly = self.poly_transformer.transform(X_train)
#         else:
#             X_train_poly = X_train

#         for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train_poly)):    # The rest of the logic proceeds with the transformed but not re-scaled data
#             X_cross_train, X_cross_val = X_train_poly[train_idx], X_train_poly[val_idx]
#             y_cross_train, y_cross_val = y_train[train_idx], y_train[val_idx]
            
#             # We add a bias column to both the training and validation sets for the model
#             X_cross_train = np.c_[np.ones(X_cross_train.shape[0]), X_cross_train]
#             X_cross_val = np.c_[np.ones(X_cross_val.shape[0]), X_cross_val]

#             self.theta = self._init_weights(X_cross_train.shape[1])
#             self.vel = np.zeros_like(self.theta)
            
#             with mlflow.start_run(run_name=f"Fold-{fold}", nested=True):
#                 params = {"method": self.method, "lr": self.lr, "reg": type(self).__name__,
#                           "init": self.init, "momentum": self.momentum, "poly_degree": self.degree}
#                 mlflow.log_params(params=params)

#                 for epoch in range(self.num_epochs):
#                     perm = np.random.permutation(X_cross_train.shape[0])
#                     X_cross_train_shuffled = X_cross_train[perm]
#                     y_cross_train_shuffled = y_cross_train[perm]
                    
#                     if self.method == 'sto':
#                         for batch_idx in range(X_cross_train.shape[0]):
#                             X_method_train = X_cross_train_shuffled[batch_idx].reshape(1, -1)
#                             y_method_train = y_cross_train_shuffled[batch_idx]
#                             train_loss = self._train(X_method_train, y_method_train)
#                     elif self.method == 'mini':
#                         for batch_idx in range(0, X_cross_train.shape[0], self.batch_size):
#                             X_method_train = X_cross_train_shuffled[batch_idx:batch_idx+self.batch_size]
#                             y_method_train = y_cross_train_shuffled[batch_idx:batch_idx+self.batch_size]
#                             train_loss = self._train(X_method_train, y_method_train)
#                     else:
#                         train_loss = self._train(X_cross_train_shuffled, y_cross_train_shuffled)
                    
#                     mlflow.log_metric(key="train_loss", value=train_loss, step=epoch)

#                     yhat_val = self.predict(X_cross_val, from_train=True)
#                     val_loss_new = self.mse(y_cross_val, yhat_val)
#                     val_r2_new = self.r2(y_cross_val, yhat_val)
                    
#                     mlflow.log_metric(key="val_loss", value=val_loss_new, step=epoch)
#                     mlflow.log_metric(key="val_r2", value=val_r2_new, step=epoch)

#                     if np.allclose(val_loss_new, self.val_loss_old):
#                         break
#                     self.val_loss_old = val_loss_new
                
#                 self.kfold_scores.append(val_loss_new)
#                 self.kfold_r2.append(val_r2_new)
#                 print(f"Fold {fold}: MSE {val_loss_new}")
#                 print(f"Fold {fold}: R2: {val_r2_new}")
    

#     #train
#     def _train(self, X, y):
#         #X shape: (m, n)
#         #y shape: (m, )
#         #theta shape: (n, )
        
#         #1. predict
#         yhat = self.predict(X)

#         #2. grad
#         m = X.shape[0]
#         grad = (1/m) * X.T @ (yhat - y) + self.regularization.derivation(self.theta)
        
#         # (n, m) @ (m, ) - (m, ) = (m, ) ===> (n, )
                
#         #3. update
#         self.theta = self.theta - self.lr * grad
        
#         #return
#         return self.mse(y, yhat)
    
    
#     #predict
#     def predict(self, X):
#         return X @ self.theta  #(m, n) @ (n, ) = (m, )  <===== y
    
#     #get theta
#     def _coef(self):
#         return self.theta[1:]
    
#     #get bias
#     def _bias(self):
#         return self.theta[0]

# %%
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import KFold
# from sklearn.preprocessing import PolynomialFeatures
# # import mlflow  # Uncomment if installed

# class LinearRegression(object):
    
#     kfold = KFold(n_splits=5)
    
#     def __init__(self, 
#                  regularization, 
#                  lr = 0.001, 
#                  init = 'xavier', 
#                  method = 'batch', 
#                  poly = True, 
#                  degree = 2,
#                  use_momentum = True, 
#                  momentum = 0.5, 
#                  bs = 50,
#                  num_epochs = 500,
#                  cv=None):
        
#         self.lr             = lr
#         self.num_epochs     = num_epochs
#         self.bs             = bs
#         self.method         = method
#         self.cv             = cv if cv is not None else self.kfold
#         self.regularization = regularization
#         self.init           = init
#         self.poly           = poly
#         self.degree         = degree
#         self.use_momentum   = use_momentum
#         self.momentum       = momentum
#         self.vel            = None
#         self.poly_transformer = None
#         self.feature_names  = None
        
#     def mse(self, ytrue, ypred):
#         return ((ypred - ytrue) ** 2).sum() / ytrue.shape[0]
    
#     def r2(self, ytrue, ypred):
#         ss_res = ((ytrue - ypred) ** 2).sum()
#         ss_tot = ((ytrue - ytrue.mean()) ** 2).sum()
#         return 1 - (ss_res / ss_tot) if ss_tot != 0 else 0.0
    
#     def xavier_init(self, n_features):
#         limit = np.sqrt(6.0 / (n_features + 1))
#         return np.random.uniform(-limit, limit, size=n_features)
    
#     def _init_weights(self, n_features):
#         if self.init == "xavier":
#             return self.xavier_init(n_features)
#         elif self.init == "zero":
#             return np.zeros(n_features)
#         else:
#             raise ValueError("init must be 'zero' or 'xavier'")

#     def fit(self, X_train, y_train):
#         self.kfold_scores = []
#         self.kfold_r2 = []
#         self.val_loss_old = np.inf

#         if isinstance(X_train, pd.DataFrame):
#             self.feature_names = X_train.columns.tolist()
#             X_train = X_train.values
#         else:
#             self.feature_names = [f"feature_{i}" for i in range(X_train.shape[1])]
            
#         if isinstance(y_train, pd.Series):
#             y_train = y_train.values

#         # Apply polynomial transformation
#         if self.poly and self.poly_transformer is None:
#             self.poly_transformer = PolynomialFeatures(degree=self.degree, include_bias=False)
#             X_train_poly = self.poly_transformer.fit_transform(X_train)
#         elif self.poly:
#             X_train_poly = self.poly_transformer.transform(X_train)
#         else:
#             X_train_poly = X_train

#         for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train_poly)):
#             X_cross_train, X_cross_val = X_train_poly[train_idx], X_train_poly[val_idx]
#             y_cross_train, y_cross_val = y_train[train_idx], y_train[val_idx]
            
#             # Add bias column
#             X_cross_train = np.c_[np.ones(X_cross_train.shape[0]), X_cross_train]
#             X_cross_val = np.c_[np.ones(X_cross_val.shape[0]), X_cross_val]

#             # Initialize weights and velocity
#             self.theta = self._init_weights(X_cross_train.shape[1])
#             if self.use_momentum:
#                 self.vel = np.zeros_like(self.theta)

#             # ========= MLflow Block - Comment out if mlflow not installed =========
#             # with mlflow.start_run(run_name=f"Fold-{fold}", nested=True):
#             #     params = {"method": self.method, "lr": self.lr, "reg": type(self).__name__,
#             #               "init": self.init, "momentum": self.momentum, "poly_degree": self.degree}
#             #     mlflow.log_params(params=params)

#             for epoch in range(self.num_epochs):
#                 perm = np.random.permutation(X_cross_train.shape[0])
#                 X_cross_train_shuffled = X_cross_train[perm]
#                 y_cross_train_shuffled = y_cross_train[perm]
                
#                 if self.method == 'sto':
#                     for batch_idx in range(X_cross_train.shape[0]):
#                         X_method_train = X_cross_train_shuffled[batch_idx].reshape(1, -1)
#                         y_method_train = y_cross_train_shuffled[batch_idx]
#                         train_loss = self._train(X_method_train, y_method_train)
#                 elif self.method == 'mini':
#                     for batch_idx in range(0, X_cross_train.shape[0], self.bs):  # ← FIXED
#                         X_method_train = X_cross_train_shuffled[batch_idx:batch_idx+self.bs]
#                         y_method_train = y_cross_train_shuffled[batch_idx:batch_idx+self.bs]
#                         train_loss = self._train(X_method_train, y_method_train)
#                 else:  # batch
#                     train_loss = self._train(X_cross_train_shuffled, y_cross_train_shuffled)
                
#                 # Optional: Log with mlflow
#                 # mlflow.log_metric(key="train_loss", value=train_loss, step=epoch)

#                 yhat_val = self.predict(X_cross_val)  # ← Removed from_train=True
#                 val_loss_new = self.mse(y_cross_val, yhat_val)
#                 val_r2_new = self.r2(y_cross_val, yhat_val)
                
#                 # mlflow.log_metric(key="val_loss", value=val_loss_new, step=epoch)
#                 # mlflow.log_metric(key="val_r2", value=val_r2_new, step=epoch)

#                 if np.allclose(val_loss_new, self.val_loss_old):
#                     print(f"Early stopping at epoch {epoch} for fold {fold}")
#                     break
#                 self.val_loss_old = val_loss_new
            
#             self.kfold_scores.append(val_loss_new)
#             self.kfold_r2.append(val_r2_new)
#             print(f"Fold {fold}: MSE = {val_loss_new:.6f}, R2 = {val_r2_new:.6f}")

#     def _train(self, X, y):
#         yhat = self.predict(X)
#         m = X.shape[0]
#         grad = (1/m) * X.T @ (yhat - y) + self.regularization.derivation(self.theta)
#         if self.use_momentum:
#             self.vel = self.momentum * self.vel + self.lr * grad
#             self.theta -= self.vel
#         else:
#             self.theta -= self.lr * grad
#         return self.mse(y, yhat)
    
#     def predict(self, X):
#         return X @ self.theta
    
#     def coef_(self):
#         return self.theta[1:]
    
#     def intercept_(self):
#         return self.theta[0]

# %%
# #Lasso
# class Lasso:
#     def __init__(self, l):
#         self.l = l
        
#     def __call__(self, theta): #__call__ allows us to call class as method
#         return self.l * np.sum(np.abs(theta))
    
#     def derivation(self, theta):
#         return self.l * np.sign(theta)

# %%
# #Ridge
# class Ridge:
#     def __init__(self, l):
#         self.l = l
        
#     def __call__(self, theta): #__call__ allows us to call class as method
#         return self.l * np.sum(np.square(theta))
    
#     def derivation(self, theta):
#         return self.l * 2 * theta

# %%
# #Elastic
# class Elastic:
#     def __init__(self, l, l_ratio):
#         self.l = l
#         self.l_ratio = l_ratio
        
#     def __call__(self, theta): #__call__ allows us to call class as method
#         l1 = self.l_ratio * self.l * np.sum(np.abs(theta))
#         l2 = (1 - self.l_ratio) * self.l * np.sum(np.square(theta)) 
#         return (l1 + l2)
    
#     def derivation(self, theta):
#         l1 = self.l * self.l_ratio * np.sign(theta)
#         l2 = 2 * self.l * (1 - self.l_ratio) * theta
#         return (l1 + l2)

# %%
# #inherits LinearRegression and has separate classes for each of this regularization algorithm

# class LassoRegression(LinearRegression):
#     def __init__(self, method, lr, l):
#         self.regularization = Lasso(l)
#         super().__init__(self.regularization, lr, method)

# %%
# class RidgeRegression(LinearRegression):
#     def __init__(self, method, lr, l):
#         self.regularization = Ridge(l)
#         super().__init__(self.regularization, lr, method)

# %%
# class ElasticRegression(LinearRegression):
#     def __init__(self, method, lr, l, l_ratio=0.5):
#         self.regularization = Elastic(l, l_ratio)
#         super().__init__(self.regularization, lr, method)

# %%
# import sys

# def str_to_class(classname):    #converts string to class
#     return getattr(sys.modules[__name__], classname)

# %%
# def str_to_class(classname):
#     return getattr(sys.modules[__name__], classname)

# type_of_regression = str_to_class(reg)
# model = type_of_regression(**params)

# regs = ["Ridge", "Lasso", "ElasticNet"]

# # Looping through all regression methods
# for reg in regs:
#     # Specifying the parameters for the model
#     params = {"method": "batch", "l": 0.1, "lr": 0.1,  "polynomial": True, "init" :"xavier", 
#     "use_momentum" :True,  "momentum":0.5, "degree":2}
#     mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}", nested=True)
    
#     print("="*5, reg, "="*5) # Printing the name of the regression method being used

#     #Specifying the type of regression and setting up the model based on it
#     type_of_regression = str_to_class(reg)    #Ridge, Lasso, ElasticNet
#     model = type_of_regression(**params) # Creating the model object
#     model.fit(X_train, y_train) # Fitting the model
#     #Calculating avgMse and r2 for the speicified params
#     mse = model.avgMSE()
#     r2 = model.avgr2()

#     yhat = model.predict(X_train)  # Predicting on the training data
    
#     print("Validation MSE: ", mse)
#     print("Validation R2: ", r2)
#     # Logging the metrics in ml flow
#     mlflow.log_metric(key="train_mse", value=mse)
#     mlflow.log_metric(key="train_r2", value=r2)

#     signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
#     mlflow.sklearn.log_model(model, name='model', signature=signature)

#     mlflow.end_run()

# %%
# import numpy as np

# class L2Regularization:
#     def __init__(self, lambd=0.01):
#         self.lambd = lambd

#     def derivation(self, theta):
#         """L2: R(w) = λ * ||w||² → ∇R(w) = 2λw (but we absorb 2 into λ for simplicity)"""
#         grad = np.copy(theta)
#         grad[0] = 0  # Do NOT regularize bias term (theta[0])
#         return self.lambd * grad


# class L1Regularization:
#     def __init__(self, lambd=0.01):
#         self.lambd = lambd

#     def derivation(self, theta):
#         """L1: R(w) = λ * ||w||₁ → ∇R(w) = λ * sign(w)"""
#         grad = np.sign(theta)
#         grad[0] = 0  # Do NOT regularize bias term
#         return self.lambd * grad


# class ElasticNetRegularization:
#     def __init__(self, lambd=0.01, l1_ratio=0.5):
#         """
#         ElasticNet = l1_ratio * L1 + (1 - l1_ratio) * L2
#         """
#         self.lambd = lambd
#         self.l1_ratio = l1_ratio

#     def derivation(self, theta):
#         l1_grad = np.sign(theta)
#         l2_grad = np.copy(theta)
#         l1_grad[0] = l2_grad[0] = 0  # Don't regularize bias
#         return self.lambd * (
#             self.l1_ratio * l1_grad +
#             (1 - self.l1_ratio) * l2_grad
#         )

# %%
# class Ridge(LinearRegression):
#     def __init__(self, l=0.01, **kwargs):  # ← Accept **kwargs
#         reg = L2Regularization(lambd=l)
#         super().__init__(regularization=reg, **kwargs)  # ← Pass **kwargs to parent


# class Lasso(LinearRegression):
#     def __init__(self, l=0.01, **kwargs):
#         reg = L1Regularization(lambd=l)
#         super().__init__(regularization=reg, **kwargs)


# class ElasticNet(LinearRegression):
#     def __init__(self, l=0.01, l1_ratio=0.5, **kwargs):
#         reg = ElasticNetRegularization(lambd=l, l1_ratio=l1_ratio)
#         super().__init__(regularization=reg, **kwargs)

# %%
# REGRESSION_MODELS = {
#     "Ridge": Ridge,
#     "Lasso": Lasso,
#     "ElasticNet": ElasticNet
# }

# %%
# regs = ["Ridge", "Lasso", "ElasticNet"]

# for reg_name in regs:
#     print("="*5, reg_name, "="*5)

#     params = {
#         "method": "batch",
#         "l": 0.1,
#         "lr": 0.1,
#         "polynomial": True,
#         "init": "xavier",
#         "use_momentum": True,
#         "momentum": 0.5,
#         "degree": 2,
#         "bs": 50,
#         "num_epochs": 500
#     }

#     # ✅ Use 'with' to auto-close run
#     with mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg_name}"):

#         ModelClass = REGRESSION_MODELS[reg_name]
#         model = ModelClass(**params)  # ← Now works thanks to **kwargs

#         model.fit(X_train, y_train)

#         mse = model.avgMSE()
#         r2 = model.avgr2()
#         yhat = model.predict(X_train)

#         print("Validation MSE: ", mse)
#         print("Validation R2: ", r2)

#         mlflow.log_metric("train_mse", mse)
#         mlflow.log_metric("train_r2", r2)

#         signature = mlflow.models.infer_signature(X_train, yhat)
#         mlflow.sklearn.log_model(model, "model", signature=signature)

#         # ✅ No need for mlflow.end_run() — handled by 'with'

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
import mlflow
import pandas as pd
import matplotlib.pyplot as plt

class LinearRegression(object):
    
    def __init__(self, regularization, lr=0.001, method='batch', init='xavier', polynomial=True, degree=2,
                 use_momentum=True, momentum=0.5, num_epochs=500, batch_size=50, cv=KFold(n_splits=3)):
        
        # Model Hyperparameters
        self.lr         = lr                     # Learning rate, controls how big of a step the model takes
        self.num_epochs = num_epochs             # Number of times the model will go through the entire dataset
        self.batch_size = batch_size             # Number of samples in each training batch
        self.method     = method                 # Gradient descent method: 'batch', 'mini', 'sto'
        self.polynomial = polynomial             # Whether to use polynomial features
        self.degree     = degree                 # The highest power for polynomial features
        self.init       = init                   # Method for initializing the model's weights: 'zeros', 'xavier'
        self.use_momentum   = use_momentum       # Whether to use momentum to speed up training
        self.momentum   = momentum               # Momentum rate
        self.prev_step  = 0                      # Keeps track of the previous step for momentum calculations
        self.cv         = cv                     # Cross-validation strategy, used to split data into folds
        self.regularization = regularization     # The regularization object (L1, L2, etc.)

        # Model Attributes
        self.theta = None                        # The model's weights, which are learned during training
        self.poly_transformer = None             # Stores the polynomial feature transformer
        self.kfold_scores = []                   # List to store the MSE for each cross-validation fold
        self.kfold_r2 = []                       # List to store the R2 score for each fold
        self.val_loss_old = np.inf               # Used for early stopping
        self.columns = None
        self.feature_names = None

    def mse(self, ytrue, ypred):  # Calculates the Mean Squared Error between true and predicted values
        ytrue = np.array(ytrue).reshape(-1)
        ypred = np.array(ypred).reshape(-1)
        return mean_squared_error(ytrue, ypred)
    
    def r2(self, ytrue, ypred):  # Calculates the R-squared score, which measures how well the model's predictions fit the data
        return r2_score(ytrue, ypred)
    
    def avgMSE(self): # Returns the average MSE across all cross-validation folds
        return np.mean(self.kfold_scores)
    
    def avgr2(self): # Returns the average R-squared score across all cross-validation folds
        return np.mean(self.kfold_r2)
    
    def _init_weights(self, n_features):
        if self.init == "xavier":
            limit = np.sqrt(16.0 / (n_features + 1))
            return np.random.uniform(-limit, limit, size=n_features)
        elif self.init == "zero":
            return np.zeros(n_features)
        else:
            raise ValueError("init must be either 'zero' or 'xavier'")


    def _transform_data(self, X): # Prepares the input data for the model
        if self.polynomial:  # If a transformer doesn't exist yet, we create and fit it to the data
            if self.poly_transformer is None:
                self.poly_transformer = PolynomialFeatures(degree=self.degree, include_bias=False)
                X = self.poly_transformer.fit_transform(X)
            else:
                X = self.poly_transformer.transform(X) # Use the existing transformer to transform the data
        return np.c_[np.ones(X.shape[0]), X]    # We add a bias (intercept) column to the data to allow the model to learn a baseline value
    
    def fit(self, X_train, y_train):        # The main function to train the model on your data
        
        self.kfold_scores = []
        self.kfold_r2 = []
        self.val_loss_old = np.inf

        if isinstance(X_train, pd.DataFrame):
            self.feature_names = X_train.columns.tolist()
            X_train = X_train.values
        else:
            self.feature_names = [f"feature_{i}" for i in range(X_train.shape[1])]
            
        if isinstance(y_train, pd.Series):
            y_train = y_train.values
        if self.polynomial and self.poly_transformer is None:                   # We prepare the polynomial features on the entire dataset first, which is more efficient
            self.poly_transformer = PolynomialFeatures(degree=self.degree, include_bias=False)
            X_train_poly = self.poly_transformer.fit_transform(X_train)
        elif self.polynomial:
            X_train_poly = self.poly_transformer.transform(X_train)
        else:
            X_train_poly = X_train

        for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train_poly)):    # The rest of the logic proceeds with the transformed but not re-scaled data
            X_cross_train, X_cross_val = X_train_poly[train_idx], X_train_poly[val_idx]
            y_cross_train, y_cross_val = y_train[train_idx], y_train[val_idx]
            
            # We add a bias column to both the training and validation sets for the model
            X_cross_train = np.c_[np.ones(X_cross_train.shape[0]), X_cross_train]
            X_cross_val = np.c_[np.ones(X_cross_val.shape[0]), X_cross_val]

            self.theta = self._init_weights(X_cross_train.shape[1])
            self.vel = np.zeros_like(self.theta)
            
            with mlflow.start_run(run_name=f"Fold-{fold}", nested=True):
                params = {"method": self.method, "lr": self.lr, "reg": type(self).__name__,
                          "init": self.init, "momentum": self.momentum, "poly_degree": self.degree}
                mlflow.log_params(params=params)

                for epoch in range(self.num_epochs):
                    perm = np.random.permutation(X_cross_train.shape[0])
                    X_cross_train_shuffled = X_cross_train[perm]
                    y_cross_train_shuffled = y_cross_train[perm]
                    
                    if self.method == 'sto':
                        for batch_idx in range(X_cross_train.shape[0]):
                            X_method_train = X_cross_train_shuffled[batch_idx].reshape(1, -1)
                            y_method_train = y_cross_train_shuffled[batch_idx]
                            train_loss = self._train(X_method_train, y_method_train)
                    elif self.method == 'mini':
                        for batch_idx in range(0, X_cross_train.shape[0], self.batch_size):
                            X_method_train = X_cross_train_shuffled[batch_idx:batch_idx+self.batch_size]
                            y_method_train = y_cross_train_shuffled[batch_idx:batch_idx+self.batch_size]
                            train_loss = self._train(X_method_train, y_method_train)
                    else:
                        train_loss = self._train(X_cross_train_shuffled, y_cross_train_shuffled)
                    
                    mlflow.log_metric(key="train_loss", value=train_loss, step=epoch)

                    yhat_val = self.predict(X_cross_val, from_train=True)
                    val_loss_new = self.mse(y_cross_val, yhat_val)
                    val_r2_new = self.r2(y_cross_val, yhat_val)
                    
                    mlflow.log_metric(key="val_loss", value=val_loss_new, step=epoch)
                    mlflow.log_metric(key="val_r2", value=val_r2_new, step=epoch)

                    if np.allclose(val_loss_new, self.val_loss_old):
                        break
                    self.val_loss_old = val_loss_new
                
                self.kfold_scores.append(val_loss_new)
                self.kfold_r2.append(val_r2_new)
                print(f"Fold {fold}: MSE {val_loss_new}")
                print(f"Fold {fold}: R2: {val_r2_new}")
    
    def _train(self, X, y):
        yhat = X @ self.theta
        m = X.shape[0]

        grad = (1/m) * X.T @ (yhat - y)

        if self.regularization is not None:
            reg_grad = self.regularization.derivation(self.theta).copy()    # Get the gradient from the regularization object
            reg_grad[0] = 0  # don’t regularize bias
            grad += reg_grad # Add the regularization gradient to the main gradient

        if self.use_momentum:   # Update weights with momentum
            self.vel = self.momentum * self.vel + self.lr * grad    # Update velocity
            self.theta = self.theta - self.vel  # Update weights using velocity
        else:
            self.theta = self.theta - self.lr * grad    # Update weights without momentum

        return self.mse(y, yhat)    # Return the training loss for this batch
    
    def predict(self, X, from_train=False): # Makes predictions on new data.
        if not from_train:                  # It handles transforming the data before making a prediction.
            if self.polynomial:
                X = self.poly_transformer.transform(X)  # Transform the data if polynomial features are used
            X = np.c_[np.ones(X.shape[0]), X]       # Add the bias column to the data
            
        return X @ self.theta
     
    def _coef(self):
        return self.theta[1:] # Returns the learned coefficients (weights) of the model, excluding the bias term
    
    def _bias(self):
        return self.theta[0]  # Returns the learned bias (intercept) of the model
    
    # def feature_importance(self, width=5, height=10):  # Creates a bar chart showing the importance of each feature
    #     #if self.theta is not None and self.columns is not None:  # Skip bias term when plotting
    #         coefs = pd.DataFrame(
    #             data=self.theta[1:],
    #             columns=['Coefficients'],
    #             index=self.columns
    #         )
    #         coefs.plot(kind="barh", figsize=(width, height))
    #         plt.title("Feature Importance")
    #         plt.show()
    #     else:
    #         print("Coefficients or feature names are not available to create the graph.")
    def feature_importance(self, width=5, height=10):
        if self.theta is not None and self.feature_names is not None:
            coefs = pd.DataFrame(
                data=self.theta[1:],  # skip bias
                columns=['Coefficients'],
                index=self.feature_names if not self.polynomial else range(len(self.theta[1:]))
            )
            coefs.plot(kind="barh", figsize=(width, height))
            plt.title("Feature Importance")
            plt.show()
        else:
            print("Coefficients or feature names are not available to create the graph.")

# %%
# Defining penalty classes for different regularization techniques
class LassoPenalty:
    
    def __init__(self, l):
        self.l = l # lambda value
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.abs(theta))
        
    def derivation(self, theta):
        return self.l * np.sign(theta) # Derivative of L1 norm is lambda*sign(theta)
    
class RidgePenalty:
    
    def __init__(self, l):
        self.l = l
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.square(theta)) 
        
    def derivation(self, theta):
        return self.l * 2 * theta # Derivative of L2 norm is 2*lambda*theta
    
class ElasticPenalty:
    
    def __init__(self, l = 0.1, l_ratio = 0.5):
        self.l = l 
        self.l_ratio = l_ratio

    def __call__(self, theta):  #__call__ allows us to call class as method
        l1_contribution = self.l_ratio * self.l * np.sum(np.abs(theta)) # L1 part
        l2_contribution = (1 - self.l_ratio) * self.l * 0.5 * np.sum(np.square(theta)) # 0.5 factor for L2
        return (l1_contribution + l2_contribution)

    def derivation(self, theta):
        l1_derivation = self.l * self.l_ratio * np.sign(theta)
        l2_derivation = self.l * (1 - self.l_ratio) * theta
        return (l1_derivation + l2_derivation)
    
# Defining subclasses for different regularization techniques    
class Lasso(LinearRegression):
    def __init__(self, l, lr, method, init, polynomial, degree, use_momentum, momentum):
        self.regularization = LassoPenalty(l)
        super().__init__(self.regularization, lr, method, init, polynomial, degree, use_momentum, momentum)
    def avgMSE(self):
        return np.sum(np.array(self.kfold_scores)) / len(self.kfold_scores)

class Ridge(LinearRegression):
    def __init__(self, l, lr, method, init, polynomial, degree, use_momentum, momentum):
        self.regularization = RidgePenalty(l)
        super().__init__(self.regularization, lr, method, init, polynomial, degree, use_momentum, momentum)
    def avgMSE(self):
        return np.sum(np.array(self.kfold_scores)) / len(self.kfold_scores)

class ElasticNet(LinearRegression):
    def __init__(self, l, lr, method, init, polynomial, degree, use_momentum, momentum, l_ratio=0.5):
        self.regularization = ElasticPenalty(l, l_ratio)
        super().__init__(self.regularization, lr, method, init, polynomial, degree, use_momentum, momentum)
    def avgMSE(self):
        return np.sum(np.array(self.kfold_scores)) / len(self.kfold_scores)

class Normal(LinearRegression):
    def __init__(self, l, lr, method, init, polynomial, degree, use_momentum, momentum):
        self.regularization = None  # No regularization
        super().__init__(self.regularization, lr, method, init, polynomial, degree, use_momentum, momentum)
    def avgMSE(self):
        return np.sum(np.array(self.kfold_scores)) / len(self.kfold_scores)

# %%
import sys

def str_to_class(classname):    #converts string to class
    return getattr(sys.modules[__name__], classname)

# %%
regs = ["Ridge", "Lasso", "ElasticNet"]

# Looping through all regression methods
for reg in regs:
    # Specifying the parameters for the model
    params = {"method": "batch", "l": 0.1, "lr": 0.1,  "polynomial": True, "init" :"xavier", 
    "use_momentum" :True,  "momentum":0.5, "degree":2}
    mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}", nested=True)
    
    print("="*5, reg, "="*5) # Printing the name of the regression method being used

    #Specifying the type of regression and setting up the model based on it
    type_of_regression = str_to_class(reg)    #Ridge, Lasso, ElasticNet
    model = type_of_regression(**params) # Creating the model object
    model.fit(X_train, y_train) # Fitting the model
    #Calculating avgMse and r2 for the speicified params
    mse = model.avgMSE()
    r2 = model.avgr2()

    yhat = model.predict(X_train)  # Predicting on the training data
    
    print("Validation MSE: ", mse)
    print("Validation R2: ", r2)
    # Logging the metrics in ml flow
    mlflow.log_metric(key="train_mse", value=mse)
    mlflow.log_metric(key="train_r2", value=r2)

    signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
    mlflow.sklearn.log_model(model, name='model', signature=signature)

    mlflow.end_run()
# Out:
# ===== Ridge =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/2bd833872951419d8c9c35930155638e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/12d0f501a4d6411dad56d0a58b3fb3ac
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/2ca76e028ba54bd59c1ae599ad92fb56
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-batch-lr-0.1-reg-Ridge at: http://localhost:5000/#/experiments/190877290999588017/runs/fe4ad1cc2b3e4222a81d7c8daa0027d4
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Lasso =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/bfccb0f9a7c94a319925b849f20c4cbc
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/10ac8a8869de48a7918dbd27d1ce74f9
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/42560b9e43a841dfbb456c7a47d34c23
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-batch-lr-0.1-reg-Lasso at: http://localhost:5000/#/experiments/190877290999588017/runs/90161e11d6554a7ea3e446316f4bed74
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== ElasticNet =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/4d18e56cd7e847cb881ab90c2fa57839
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/cd810f19d1b34c43a293b60e5cc4d1bb
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/aeda1d87e71d40359504d7aac3debc9a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-batch-lr-0.1-reg-ElasticNet at: http://localhost:5000/#/experiments/190877290999588017/runs/4e1c3e2ac7ff436abfe41708d6227af6
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017

# %%
# Setting up the experiment of polynomial and regularization type all others are hard quoted
regs = ["Ridge", "Lasso", "ElasticNet","Normal"]
ispoly= [True, False]

for reg in regs:
    for t in ispoly:

        params = {"method": "batch","polynomial": t,  "lr": 0.1, "l": 0.1, "init" :"xavier", 
        "degree":2, "use_momentum" :True,  "momentum":0.5}
        mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{t}", nested=True)
        
        print("="*5, reg, "="*5)

        type_of_regression = str_to_class(reg)   
        model = type_of_regression(**params)  
        model.fit(X_train, y_train)
        yhat = model.predict(X_train)
        mse = model.avgMSE()
        r2 = model.avgr2()
        

        print("Validation MSE: ", mse)
        print("Validation R2: ", r2)

        mlflow.log_metric(key="train_mse", value=mse)
        mlflow.log_metric(key="train_r2", value=r2)

        signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
        mlflow.sklearn.log_model(model, name='model', signature=signature)

    mlflow.end_run()
# Out:
# ===== Ridge =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/691e5146f87b469489404c2a63e329e1
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/73c3e68521d04f0fa04d8d8051c9d8ef
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/bc7bcc26ef9e42519e9ff54e11a3502e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# ===== Ridge =====
# Fold 0: MSE 272218695952.0297
# Fold 0: R2: 0.5961675314314103
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/59b35b5efa244797a2a7505f96e0474b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 240159311215.93466
# Fold 1: R2: 0.6136665057009172
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/c4b41693b214461a9d5ca37c4be72ede
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240497701481.87366
# Fold 2: R2: 0.6031202821828807
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/a7625ddec52645e3811a91113fc6ba83
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  250958569549.946
# Validation R2:  0.6043181064384028
# 🏃 View run method-batch-lr-0.1-reg-Ridge-poly-False at: http://localhost:5000/#/experiments/190877290999588017/runs/13e0c3bb06b14c92aa20c5542d92ae62
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Lasso =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/da9dc1214e7d4914acca2b6d22670bed
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/d05e01db48eb4c6cb44b00daf9ea8d66
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/616402691f16486094136c6f287e2baa
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# ===== Lasso =====
# Fold 0: MSE 253698484891.38855
# Fold 0: R2: 0.6236419946561844
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/03ed3ec0cbb846f2828c88cb193f37f6
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 231809602914.29694
# Fold 1: R2: 0.6270983063178392
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/67ef9e247462464bbe265af3dbec28e6
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 239427115735.6189
# Fold 2: R2: 0.6048870091256107
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/ffc6b95baaaf46589ada2a4da59c61e4
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  241645067847.10147
# Validation R2:  0.6185424366998781
# 🏃 View run method-batch-lr-0.1-reg-Lasso-poly-False at: http://localhost:5000/#/experiments/190877290999588017/runs/1ee35b56506d4e62975ccba08e57da0b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== ElasticNet =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/4dfc8f00a44948ac911ee532efc8f262
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/c6fda8bbe5094d7f9d39bcf1ceae4944
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/0860a7e0c188402bbf3b1f769a765b15
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# ===== ElasticNet =====
# Fold 0: MSE 257183411348.1788
# Fold 0: R2: 0.6184721570412339
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/54ed3d4b68794a78acc377e2bcb9a289
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 232301505800.6133
# Fold 1: R2: 0.6263070042443771
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/8f739d7d8ae7424a8e0806f132899a14
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 238111062175.00964
# Fold 2: R2: 0.6070588176815697
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/19d97302f61349f5adb01f44beebff31
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  242531993107.93393
# Validation R2:  0.6172793263223936
# 🏃 View run method-batch-lr-0.1-reg-ElasticNet-poly-False at: http://localhost:5000/#/experiments/190877290999588017/runs/828ef69683b04d94b6b29c6408a60be3
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Normal =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/7837e7f13c2a47f28beddbf9f4ac0777
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/a7b38cb6ba424f6dac212b264a096986
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/8a19f72cc3d24f6fade4ec376cc6d6bf
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# ===== Normal =====
# Fold 0: MSE 253698462901.27182
# Fold 0: R2: 0.6236420272782022
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/744f45074125405dbe0f617b97af5da4
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 231809608315.22128
# Fold 1: R2: 0.627098297629615
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/6c2f380131a9415ab31fff80a26effdc
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 239427171972.96222
# Fold 2: R2: 0.6048869163203122
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/0acd08af42984d2ebc86fb96ab8e1e5f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  241645081063.15176
# Validation R2:  0.6185424137427097
# 🏃 View run method-batch-lr-0.1-reg-Normal-poly-False at: http://localhost:5000/#/experiments/190877290999588017/runs/e87f15223b134bac8a275e9da7834b0f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017

# %%
reg = "Normal"
ispoly= False
# Only testing with the method here
methods=["mini","batch","sto"]

for method in methods:
    params = {"method": method,"polynomial": ispoly,  "lr": 0.1, "l": 0.1, "init" :"xavier", 
    "degree":2, "use_momentum" :True,  "momentum":0.5}
    mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{ispoly}", nested=True)
    
    print("="*5, reg, "="*5)
    print("Method: ", method)

    type_of_regression = str_to_class(reg)    
    model = type_of_regression(**params)  
    model.fit(X_train, y_train)
    yhat = model.predict(X_train)
    mse = model.avgMSE()
    r2 = model.avgr2()

    print("Validation MSE: ", mse)
    print("Validation R2: ", r2)

    mlflow.log_metric(key="train_mse", value=mse)
    mlflow.log_metric(key="train_r2", value=r2)

    signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
    mlflow.sklearn.log_model(model, name='model', signature=signature)

    mlflow.end_run()
# Out:
# ===== Normal =====
# Method:  mini
# Fold 0: MSE 1356491500226.5688
# Fold 0: R2: -1.0123353732667106
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/0b07f4d3d4ae427fbb3dd7a8175f61e8
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 1048997737969.0112
# Fold 1: R2: -0.6874755326767956
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/24475856f1094963923faa3fc8d18b27
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 231194789102.59436
# Fold 2: R2: 0.6184723509021073
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/5c93ceb13ebb4d72abb14a0b65ec2375
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  878894675766.0581
# Validation R2:  -0.36044618501379966
# 🏃 View run method-mini-lr-0.1-reg-Normal-poly-False at: http://localhost:5000/#/experiments/190877290999588017/runs/387ab2ff0ece468a8083c485e1444eb1
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Normal =====
# Method:  batch
# Fold 0: MSE 253698463278.77008
# Fold 0: R2: 0.623642026718189
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/75016c00802f4490b6f4e3e448669663
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 231809611764.06973
# Fold 1: R2: 0.6270982920816074
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/a36bc7890baa4ea99e3dbc4e995dc2f9
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 239427171525.67346
# Fold 2: R2: 0.6048869170584474
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/1f953a50cfd8480788100275a26d132e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  241645082189.50443
# Validation R2:  0.618542411952748
# 🏃 View run method-batch-lr-0.1-reg-Normal-poly-False at: http://localhost:5000/#/experiments/190877290999588017/runs/eed37e693d5542ffa71ccca8b46c084e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Normal =====
# Method:  sto
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/f730bfa0b0524078a3e5a0f7bcf68931
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/ad8554414127423686dae16e42d17730
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/bff802bc30c140bf96a0a0e4b511c865
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.1-reg-Normal-poly-False at: http://localhost:5000/#/experiments/190877290999588017/runs/fd463e594ba14f77b9bbd7264e8bc2bd
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017

# %%
reg = "Normal"
ispoly= False
# Only testing with the best performing methods here
methods=["mini", "batch"]
# Testing with/without momentum here
momentums =[True, False]

for method in methods:
    for momentum in momentums:
        params = {"method": method,"polynomial": ispoly,  "lr": 0.1, "l": 0.01, "init" :"xavier", 
        "degree":2, "use_momentum" :momentum,  "momentum":0.5}
        mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{ispoly}-momentum-{momentum}", nested=True)    
        print("="*5, reg, "="*5)
        print("Method: ", method)
        print("Momentum: ", momentum)
        print("Inititalization: ", "Xavier")
        print("Learning Rate: ", "0.1")
        print("="*10)

        type_of_regression = str_to_class(reg)    
        model = type_of_regression(**params)  
        model.fit(X_train, y_train)
        yhat = model.predict(X_train)
        mse = model.avgMSE()
        r2 = model.avgr2()

        print("Validation MSE: ", mse)
        print("Validation R2: ", r2)

        mlflow.log_metric(key="test_mse", value=mse)
        mlflow.log_metric(key="test_r2", value=r2)

        signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
        mlflow.sklearn.log_model(model, name='model', signature=signature)

        mlflow.end_run()
# Out:
# ===== Normal =====
# Method:  mini
# Momentum:  True
# Inititalization:  Xavier
# Learning Rate:  0.1
# ==========
# Fold 0: MSE 246601094016.168
# Fold 0: R2: 0.6341708705936461
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/b0d32675187b4084a09f1171ee305202
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 242025412817.63736
# Fold 1: R2: 0.6106645918927339
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/9b5826994c9c4575a90b83ca531bcab1
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 265641815512.4757
# Fold 2: R2: 0.5616263767536893
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/b0c6fca902cc484cb85cad77b87d1998
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  251422774115.427
# Validation R2:  0.6021539464133564
# 🏃 View run method-mini-lr-0.1-reg-Normal-poly-False-momentum-True at: http://localhost:5000/#/experiments/190877290999588017/runs/092c2a014208465cbb694b1c96d093fb
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Normal =====
# Method:  mini
# Momentum:  False
# Inititalization:  Xavier
# Learning Rate:  0.1
# ==========
# Fold 0: MSE 253878878879.18314
# Fold 0: R2: 0.6233743828040623
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/af0bd5652c1d45e89ff61e2cbf18b31b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 235327600742.74213
# Fold 1: R2: 0.6214390612645514
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/ca3ef85a3e75413eb5eb13b3d66e3249
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 248089814543.2683
# Fold 2: R2: 0.590591448556298
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/29cc671c93fb4660863220e9f3455940
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  245765431388.39786
# Validation R2:  0.6118016308749705
# 🏃 View run method-mini-lr-0.1-reg-Normal-poly-False-momentum-False at: http://localhost:5000/#/experiments/190877290999588017/runs/60001d83e7b94a86aa1b926a8f9843e2
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Normal =====
# Method:  batch
# Momentum:  True
# Inititalization:  Xavier
# Learning Rate:  0.1
# ==========
# Fold 0: MSE 253698462941.4424
# Fold 0: R2: 0.6236420272186097
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/73ff9857ecdf425ab5d524834674abac
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 231809611645.09784
# Fold 1: R2: 0.6270982922729922
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/91039e504956449ca6f025c73da26ba6
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 239427171382.3326
# Fold 2: R2: 0.6048869172949948
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/ccbca917a56d4e8b833a73eca84e221b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  241645081989.6243
# Validation R2:  0.6185424122621989
# 🏃 View run method-batch-lr-0.1-reg-Normal-poly-False-momentum-True at: http://localhost:5000/#/experiments/190877290999588017/runs/53610721845343f2af6badc981a8e9fa
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Normal =====
# Method:  batch
# Momentum:  False
# Inititalization:  Xavier
# Learning Rate:  0.1
# ==========
# Fold 0: MSE 253729193781.79633
# Fold 0: R2: 0.6235964384647664
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/dfe7a0636f87433c950e181829901d62
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 231868121787.71155
# Fold 1: R2: 0.6270041696352586
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/e3a5d68360dc4b91a55946e55d3ae78e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 239500191914.40002
# Fold 2: R2: 0.6047664156520136
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/66379b6da75e4900b65c5527cb2ccdb8
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  241699169161.30264
# Validation R2:  0.6184556745840128
# 🏃 View run method-batch-lr-0.1-reg-Normal-poly-False-momentum-False at: http://localhost:5000/#/experiments/190877290999588017/runs/817b22d2724848cbab9a598703862fef
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017

# %%
reg = "Normal"
ispoly= False
methods=["mini", "batch"]
momentum =False
inits=["zero",'xavier'] # Testing with different initialization methods here
for method in methods:
    for init in inits:
        params = {"method": method,"polynomial": ispoly,  "lr": 0.1, "l": 0.1, "init" :init, 
        "degree":2, "use_momentum" :momentum,  "momentum":0.9}
        mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{ispoly}-momentum-{momentum}-init-{init}", nested=True)
        
        print("="*5, reg, "="*5)
        print("Method: ", method)
        print("Momentum: ", momentum)
        print("Inititalization: ", init)
        print("Learning Rate: ", "0.1")
        print("="*10)
        type_of_regression = str_to_class(reg)   
        model = type_of_regression(**params)  
        model.fit(X_train, y_train)
        yhat = model.predict(X_train)
        mse = model.avgMSE()
        r2 = model.avgr2()
        print("Validation MSE: ", mse)
        print("Validation R2: ", r2)
        mlflow.log_metric(key="train_mse", value=mse)
        mlflow.log_metric(key="train_r2", value=r2)
        signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
        mlflow.sklearn.log_model(model, name='model', signature=signature)

        mlflow.end_run()
# Out:
# ===== Normal =====
# Method:  mini
# Momentum:  False
# Inititalization:  zero
# Learning Rate:  0.1
# ==========
# Fold 0: MSE 261111446176.60934
# Fold 0: R2: 0.6126449746141017
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/56ca2e8c7f4441f88d192ade11af8962
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 236670685375.00137
# Fold 1: R2: 0.6192785013574922
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/07aff9c934884750aa40aa9263e2f304
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 236813990342.5551
# Fold 2: R2: 0.6091993017680335
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/f86a64e819df4d41be88a817e22e8597
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  244865373964.72192
# Validation R2:  0.6137075925798757
# 🏃 View run method-mini-lr-0.1-reg-Normal-poly-False-momentum-False-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/33b9da6489e14861812040b7d52610b8
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Normal =====
# Method:  mini
# Momentum:  False
# Inititalization:  xavier
# Learning Rate:  0.1
# ==========
# Fold 0: MSE 258356813126.00925
# Fold 0: R2: 0.6167314326030875
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/b0d7473e900b49b3be481dd54428a85d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 396092361575.41547
# Fold 1: R2: 0.36282401320256286
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/e0e0310bb1ef425e8756a67c15ed7e2c
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 229595091111.4115
# Fold 2: R2: 0.6211122417759962
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/9a3e8c87d82e452ebdd8d9e7a6f6b3f5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  294681421937.61206
# Validation R2:  0.5335558958605489
# 🏃 View run method-mini-lr-0.1-reg-Normal-poly-False-momentum-False-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/f371c14c573d4a4799ee647c7001c74c
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Normal =====
# Method:  batch
# Momentum:  False
# Inititalization:  zero
# Learning Rate:  0.1
# ==========
# Fold 0: MSE 253729193661.1908
# Fold 0: R2: 0.623596438643683
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/5fa08896ea24478b9088236120d4d87e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 231868114580.97678
# Fold 1: R2: 0.6270041812284091
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/83d9fb1972c743949a64704b164c8234
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 239500193328.25537
# Fold 2: R2: 0.6047664133188082
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/e31f5869390346e68ec9f6d0940096a2
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  241699167190.141
# Validation R2:  0.6184556777303001
# 🏃 View run method-batch-lr-0.1-reg-Normal-poly-False-momentum-False-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/c72cb537943e436f92159ed9a141d4f7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Normal =====
# Method:  batch
# Momentum:  False
# Inititalization:  xavier
# Learning Rate:  0.1
# ==========
# Fold 0: MSE 253729194035.35175
# Fold 0: R2: 0.6235964380886206
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/29fb5f5d9b37412eb8977fb2eb607447
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 231868114657.9846
# Fold 1: R2: 0.6270041811045302
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/c7d1effb26854141b031215c95e2b0c5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 239500190833.05542
# Fold 2: R2: 0.6047664174364953
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/83d5e260c2744a1ab2ef0af8b31c5dda
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  241699166508.79724
# Validation R2:  0.6184556788765487
# 🏃 View run method-batch-lr-0.1-reg-Normal-poly-False-momentum-False-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/df720d4392084910b814a30eb3074c2f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017

# %%
regs = ["Ridge", "Lasso", "ElasticNet","Normal"]
ispoly= [True, False]
lrs=[0.01,0.001,0.0001]
methods = ["sto","mini","batch"]
inits =['zero','xavier']
use_momentums =[True, False]
momentum =""
for reg in regs:
    print("="*5, reg, "="*5)
    for method in methods:
        print("="*5, method, "="*5)
        for t in ispoly:
            if t==True:
                print("=====Polynomial=====")
            else:
                print("=====Linear=====")
            for init in inits:
                print("="*5, init, "="*5)
                for use_momentum in use_momentums:
                    if(use_momentum== True):
                         momentum = "Momentum Used"
                    else:
                        momentum ="Momentum not used"
                    print("="*5, momentum, "="*5)
                    for lr in lrs:
                        print("="*5, lr, "="*5)
                        params = {"method": method,"polynomial": t,  "lr": lr, "l": 0.1, "init" :init, 
                        "degree":2, "use_momentum" :use_momentum,  "momentum":0.5}
                        mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{t}-momentum-{momentum}-init-{init}", nested=True)                                            
                        type_of_regression = str_to_class(reg)    
                        model = type_of_regression(**params)  
                        model.fit(X_train, y_train)
                        yhat = model.predict(X_train)
                        mse = model.avgMSE()
                        r2 = model.avgr2()

                        print("Validation MSE: ", mse)
                        print("Validation R2: ", r2)

                        mlflow.log_metric(key="train_mse", value=mse)
                        mlflow.log_metric(key="train_r2", value=r2)

                        signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
                        mlflow.sklearn.log_model(model, name='model', signature=signature)


                        mlflow.end_run()
# Out:
# ===== Ridge =====
# ===== sto =====
# =====Polynomial=====
# ===== zero =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/b44ac1ae3a3a49e7a0c7444605bb081f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/3911db76c9354f028cdc0243e7644a84
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/ea20952645024f5180155a8f48964f63
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.01-reg-Ridge-poly-True-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/25957061b4d1472eaee6201a10eb7427
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/ddd055ad9fe1499ca35af2ac94ba8c2a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/66b5c8adadca407fb6857d95ec2c717a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/7e489f4869b04258bc502f49518aa56e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.001-reg-Ridge-poly-True-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/02c75ad14897499c86bfc1de01af4aa6
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/934bf904bf3d4e93a088d2994ae25fa7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/fc8750db71804449a2d766e86596bc3a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 1.0032961171049445e+255
# Fold 2: R2: -1.6556826838265364e+243
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/84b03437e38d4cbd840ec5aaeb9332c6
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.0001-reg-Ridge-poly-True-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/da0f2badd08b41ef9199cf9e07a92374
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Momentum not used =====
# ===== 0.01 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/ca8c9daad8334092aef5cfe5a4d57554
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/4f14170bef9f4ce9bb5212d081fb41c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/0726af866b6e46b1ac2a3e10106f71fb
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.01-reg-Ridge-poly-True-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/0c880f49fb3344fe85b965a239c9cebc
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/972fc5b8da9e4f88858aaa9b9313b6fe
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/9ffd78247f2f48869df2c3fec2957bf6
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/b5de1395aace466f8010bd2bbd2fb37e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.001-reg-Ridge-poly-True-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/410604e4b38043d2bc41fad3322f70e7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/b46186083bfa4e7ab1f53ee4557f0033
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/11ede52be4504bfdad011991e92a0f23
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/7bca4b252f24482aa8c2df4dda90159a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.0001-reg-Ridge-poly-True-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/f42496fdd9f04f26bfaf88928822090f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== xavier =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/6c3c8b3d7d224a75af09aa7e1f606b05
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/4cb040d57fa64564a155dd90e7921b53
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/bd7e40bf0cbb4efabd6250384b22e47d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.01-reg-Ridge-poly-True-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/ef5901edc1c4404fb48892e3e1a13dfa
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/e26c0b081a75460ab561f85412da187d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/f7d10195ae3c45c59bc13831ecf8a668
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/20a35dd038964692b541eb2787985d9d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.001-reg-Ridge-poly-True-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/7b73d68c972b415395ffffa909be8e94
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/b6065eedb3eb4f458ad1eb3289082ed7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/ba891196b8cc4548938fedec55967304
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 5.123948539816494e+269
# Fold 2: R2: -8.455761689452496e+257
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/b015f63099cc4b7f9bbe6faae7b5fb78
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.0001-reg-Ridge-poly-True-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/fbd7ff1e5fbe42fba3cdb011024499f4
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Momentum not used =====
# ===== 0.01 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/854536607e8a4e1fb88efeb89ae16977
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/85bd6f737ded482eb3e8c469768c9de2
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/3f17b4d950304ef780db9305275b731c
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.01-reg-Ridge-poly-True-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/2acd4cedeaf74346831f1a15600762a0
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/ee34766c250042339946043df96815a7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/6e680a74f03542a5a49471668deaa31c
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/b500850c7d0c420d9a403b4cf85620d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.001-reg-Ridge-poly-True-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/2309a9e24aeb4feb894d2cae2c1a8f94
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/3c924b01723d418386c4f40ffe9732b8
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/5cb023a73084438ebe9f3a34b98c5b09
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/902658f8c0844356a38d9c4fe4f72878
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-sto-lr-0.0001-reg-Ridge-poly-True-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/ac1aa22d788848e18b8d54285b30960a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# =====Linear=====
# ===== zero =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE 330491192830.2435
# Fold 0: R2: 0.509721131481969
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/cfc91b5fe74b4007b9670dc32d6f9c45
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 291567489841.15247
# Fold 1: R2: 0.5309684783653272
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/1e0d0a37903448aabb9be54fee0ecb08
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 322701765660.73596
# Fold 2: R2: 0.4674635769682316
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/f91780410ba2498dba790c77e2102f12
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  314920149444.044
# Validation R2:  0.5027177289385093
# 🏃 View run method-sto-lr-0.01-reg-Ridge-poly-False-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/584fab7c3503450eadc87e3515c05701
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 277292891316.14465
# Fold 0: R2: 0.5886400365518856
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/805e0e1f08904677a37f6e3f4837a356
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 241133984294.71884
# Fold 1: R2: 0.6120985929082821
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/0801107046d747818a6ca135483d4ce7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240156078491.71863
# Fold 2: R2: 0.6036840432296482
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/f07c520ae2394070b2ab9c3e1837889a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  252860984700.86072
# Validation R2:  0.6014742242299386
# 🏃 View run method-sto-lr-0.001-reg-Ridge-poly-False-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/a4bc9c88aabf4f429c69df285af5c30d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 269430507511.36807
# Fold 0: R2: 0.6003037683525703
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/4fa141fe76a7498aad4bacf5467b5e64
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 242221328496.5114
# Fold 1: R2: 0.6103494311420465
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/5354bd3906384214a2c5cdc804a2570c
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240121161775.1362
# Fold 2: R2: 0.6037416643068516
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/3d56b87e34544a65852fcc2ab2d36ba2
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  250590999261.00525
# Validation R2:  0.6047982879338228
# 🏃 View run method-sto-lr-0.0001-reg-Ridge-poly-False-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/9b51e930768046e084fe4391fb2fd344
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Momentum not used =====
# ===== 0.01 =====
# Fold 0: MSE 332830947680.1435
# Fold 0: R2: 0.5062501392579561
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/882e865ab3b54e7f9ccbab993d052a7f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 331928520649.07544
# Fold 1: R2: 0.4660415014074454
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/28c9b80cf9084821b456872e3ab08d74
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 255219531343.54657
# Fold 2: R2: 0.5788256812563404
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/767dce05ac474971a1568171a4aac5e2
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  306659666557.58856
# Validation R2:  0.5170391073072472
# 🏃 View run method-sto-lr-0.01-reg-Ridge-poly-False-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/7c2ee5a3a1224c36ae3b26e9e1954063
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 282774752302.75836
# Fold 0: R2: 0.5805077756620451
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/beb313b01be24fdfbaaf11fdd05d1e99
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 238446550893.66843
# Fold 1: R2: 0.6164217462820455
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/62835406494842f2947a9b4ceac3b5da
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 233893364921.9262
# Fold 2: R2: 0.6140190442672193
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/1c0792e2634b4b6cbf565c3786977bb5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  251704889372.78433
# Validation R2:  0.6036495220704367
# 🏃 View run method-sto-lr-0.001-reg-Ridge-poly-False-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/ea0a6feb3f014fc7bdf63653aff4929a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 272921762397.86993
# Fold 0: R2: 0.5951245426043629
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/ba0188b160e7490e885abc951814c5fd
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 240028286318.86414
# Fold 1: R2: 0.61387727956627
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/2195b7b7ca694139a108c419a1329e4f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240164858121.80914
# Fold 2: R2: 0.6036695547040141
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/d6001138cd904f88902257bd42c57421
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  251038302279.5144
# Validation R2:  0.604223792291549
# 🏃 View run method-sto-lr-0.0001-reg-Ridge-poly-False-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/6df6766d402a49efad591316acd7c2bd
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== xavier =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE 265655962383.37442
# Fold 0: R2: 0.6059032510458157
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/80001dd07d6d4bfcaac8b9443e406805
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 243786836262.3868
# Fold 1: R2: 0.6078310691327584
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/4423ce3c595645c7b72764914294e7a5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 277418114913.86865
# Fold 2: R2: 0.5421926177008736
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/df5f975c35a4474f87c0b500a61d3ac1
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  262286971186.5433
# Validation R2:  0.5853089792931492
# 🏃 View run method-sto-lr-0.01-reg-Ridge-poly-False-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/91dc68157f8a4594ba95fa75189b06e0
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 284561978064.59503
# Fold 0: R2: 0.5778564522885061
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/d8afbc934cfe486b9f82d44258e8d37f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 266465397728.6899
# Fold 1: R2: 0.5713490861832168
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/f51d1f34fe004542910d393070fe9895
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 234055189778.08176
# Fold 2: R2: 0.6137519938844046
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/477e29361e4a4ab088085ec782ec4baa
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  261694188523.7889
# Validation R2:  0.587652510785376
# 🏃 View run method-sto-lr-0.001-reg-Ridge-poly-False-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/1146a7ed34f24a2ab160197a11d203d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 272303313923.2161
# Fold 0: R2: 0.5960420019042412
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/a5e42665e8294a5bbbe76f81fa8232aa
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 240151544858.80853
# Fold 1: R2: 0.6136789990907063
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/6c1aba0279d54fc0aadc14265ad596fe
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240851970527.7133
# Fold 2: R2: 0.6025356520675914
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/cef5605a20174038aa9a7ceae67d11c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  251102276436.5793
# Validation R2:  0.6040855510208463
# 🏃 View run method-sto-lr-0.0001-reg-Ridge-poly-False-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/b109035a96984a3faf971a6b35540654
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Momentum not used =====
# ===== 0.01 =====
# Fold 0: MSE 252564003944.18353
# Fold 0: R2: 0.6253249806092676
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/7cd16816817c45cf8752ced141ae0b78
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 249864078881.9171
# Fold 1: R2: 0.5980548819634197
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/b0a525d333ee470cb1644b7a94db6e13
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 292087892132.32416
# Fold 2: R2: 0.5179839162994613
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/bf2fe7fc246e45b7a2f93ed7a5010972
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  264838658319.47495
# Validation R2:  0.5804545929573829
# 🏃 View run method-sto-lr-0.01-reg-Ridge-poly-False-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/84a1fd6bc58949f0932757e8ac2cd1b9
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 281843351469.596
# Fold 0: R2: 0.5818894952253078
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/cabf9e927e484102b8a1088e958a276b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 295078864788.63885
# Fold 1: R2: 0.5253198872430913
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/c269927b35e7484db620dedd82e2110c
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 242796506971.03152
# Fold 2: R2: 0.599326693852382
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/7a269e9faa17449ebad6f0f521ac221f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  273239574409.75546
# Validation R2:  0.5688453587735937
# 🏃 View run method-sto-lr-0.001-reg-Ridge-poly-False-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/6d22ef03f374434e92e61ce29eda7676
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 271838288882.15656
# Fold 0: R2: 0.596731859776128
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/e6f9cdded78d4f64af798b1997cafccc
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 240591459813.79242
# Fold 1: R2: 0.6129713276667135
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/26fb1b5d42fc4a709817bf11809d7123
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240252608990.68857
# Fold 2: R2: 0.6035247444215686
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/90047621586846dbada4f17747e4a2cf
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  250894119228.87918
# Validation R2:  0.60440931062147
# 🏃 View run method-sto-lr-0.0001-reg-Ridge-poly-False-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/4d77b49a13fe479189796b1b14ee42d0
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== mini =====
# =====Polynomial=====
# ===== zero =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/0df46a8caa124e55a0091bd86735c3f3
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/f29dd4c808b14e089122d9e03b5de9ca
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/a69d3c1e23cb4a5695fad7eef4154306
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.01-reg-Ridge-poly-True-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/fcd83edef2b0495cb8dae5e1d74e2f6f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/da56cde2ce22434fb14945caddde668e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/a6d66c2da6a44f778fa9389abea40011
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/59a18c54af84433288a73c32f9511779
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.001-reg-Ridge-poly-True-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/976859d788d045649072ec28ed8cc6e4
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 3.392504362118499e+304
# Fold 0: R2: -5.032730784315577e+292
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/9a6a6042582a4deebdb737500fb3c5c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/8ef5efbea36146b4b3c72046618ee489
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 211750784849.09204
# Fold 2: R2: 0.6505596884268133
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/bd52ec75723045b7b91df38d624fd14e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.0001-reg-Ridge-poly-True-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/96697f6ebf5941adace37bfeb51e819a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Momentum not used =====
# ===== 0.01 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/15e0d4518c0241c6af9ce195a9df903e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/4def7e65708d40cc93aecd59d4090ff9
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 1.3828225130680975e+284
# Fold 2: R2: -2.2819935716474627e+272
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/46e4912fe722496084c5fe88c2a83eb7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.01-reg-Ridge-poly-True-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/95789a6086904ea3aeef755b0d50ff2d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/fb36ff2286a24269845eefc7598005b5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/643e1480723f4f75a5d31ea0d0b3e186
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/8f0bca5628cf45b6b5b4fb8137168294
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.001-reg-Ridge-poly-True-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/e994e8be14d245c1bedabf27b9177247
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 3.694802152723576e+75
# Fold 0: R2: -5.481185151477748e+63
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/128554a5b6ea44aa88aadde83da65e88
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/b4273f5c2d7a4c68b29349950c5caff0
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 238484007222.91156
# Fold 2: R2: 0.6064433676192174
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/ff0a7d5124734d71af5f7bdbbf66ec5e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.0001-reg-Ridge-poly-True-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/92e7228c74e54a88bf5289d3ce61bbf2
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== xavier =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/f122267c88444a9daa4beaf49b793f34
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/93a2f447fc154988884f8b9754d6824b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/7ead3c8e00614c6080e058b83b18ee1d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.01-reg-Ridge-poly-True-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/b78a28fa7abd44f5ba658de3bce804bb
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/443ed9dd8973487da58198e4c9be473d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/44ce42fdab0b42f8a31d8e668b392aea
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/caac08f7f8a74711896b3a624f538bf4
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.001-reg-Ridge-poly-True-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/8625062a96a64801bb51b059a8342f98
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 1.4650859666398795e+300
# Fold 0: R2: -2.1734336817102426e+288
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/b8200f0d891d48f697a72d5221b443b6
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/c13957ae827a43dfa8ef21dfd8c0e587
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 213640506663.60498
# Fold 2: R2: 0.6474411876849122
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/763a223505a14fe582ef84c58edf19a0
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.0001-reg-Ridge-poly-True-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/d6b4d0097ad64ea0bc77cf9b07f7498a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Momentum not used =====
# ===== 0.01 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/3de239883c0c4b928a726fca8c2b3068
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/8dee2e18a7404be585c1ce53ed347358
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 6.44403933332396e+286
# Fold 2: R2: -1.0634232661906708e+275
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/11e281aba37a48fca6477fa801df3842
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.01-reg-Ridge-poly-True-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/5ac51acbb74d48d9b1cab5ced8b051b9
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE inf
# Fold 0: R2: -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/fb87a46beae149cf951cd7f1c3e5499c
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/8184cc81830c46df9e32c7826f4230ed
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE inf
# Fold 2: R2: -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/9625d4ce4fd143949d80403378d8c663
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.001-reg-Ridge-poly-True-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/947ef4e5950e49699d22e15052ce5cd5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 6.843864749397084e+65
# Fold 0: R2: -1.0152773624283352e+54
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/eafba868058d49d5ad542172904b5cb0
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE inf
# Fold 1: R2: -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/2a1fa209990b472fb5e93aa1d519a822
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240199642470.34192
# Fold 2: R2: 0.6036121520662963
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/a8a98047f17c490a9bd9aec50810c1c3
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  inf
# Validation R2:  -inf
# 🏃 View run method-mini-lr-0.0001-reg-Ridge-poly-True-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/609d3f4e61d64546882cc20f00be1963
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# =====Linear=====
# ===== zero =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE 270855574633.76407
# Fold 0: R2: 0.5981897020431257
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/8252a0f4da524d71a560307f5c598cc7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 237965537018.99005
# Fold 1: R2: 0.6171955316916969
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/033ab7fdaa4f4a40b8ee5d88b32110ef
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240452145939.7113
# Fold 2: R2: 0.6031954599105971
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/2d4476adf4f244959f74f5fe151d52b1
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  249757752530.8218
# Validation R2:  0.6061935645484732
# 🏃 View run method-mini-lr-0.01-reg-Ridge-poly-False-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/ced2af135fb24097b30faf330fd2ce8d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 272302316808.45215
# Fold 0: R2: 0.5960434811094631
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/8b45fe021d4045abb9dbb1c91b2186ab
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 240525645452.99222
# Fold 1: R2: 0.6130772002720863
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/9c86355899e64433b49ad9715bfa8521
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 241288764007.65665
# Fold 2: R2: 0.601814836558769
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/b6543012f4b7460989257e4250c4edfc
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  251372242089.70032
# Validation R2:  0.6036451726467728
# 🏃 View run method-mini-lr-0.001-reg-Ridge-poly-False-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/f7239a814dd94da59823e3899d2848fd
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 274954474613.9216
# Fold 0: R2: 0.5921090436533197
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/1f8d390c6d2c467a93054494f5bd143f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 241120423735.1982
# Fold 1: R2: 0.6121204071711466
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/2bf5948c6d8d4f66bded5f1b1c230852
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 242717663622.1577
# Fold 2: R2: 0.5994568045597193
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/dddd5d0e2bd3470f9a73ad6219242dc8
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  252930853990.4258
# Validation R2:  0.6012287517947286
# 🏃 View run method-mini-lr-0.0001-reg-Ridge-poly-False-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/2f3510ec4a9b4bb9a1508aec1fbee33e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Momentum not used =====
# ===== 0.01 =====
# Fold 0: MSE 275267624407.2652
# Fold 0: R2: 0.5916444904982345
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/ad9da82a73df47a1832ff574b39d38a8
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 240261076955.34717
# Fold 1: R2: 0.6135027997279607
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/4fea459cdee74e3b85d9c2f4901a99de
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240341064035.0474
# Fold 2: R2: 0.6033787720782642
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/391e4e3d57574199bda20e7e249f2e56
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  251956588465.8866
# Validation R2:  0.6028420207681532
# 🏃 View run method-mini-lr-0.01-reg-Ridge-poly-False-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/4bde788f0dcc4036b8ed620366b3c033
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 272640884264.6994
# Fold 0: R2: 0.5955412212218564
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/20211fe8ffb4414caec0950c44049981
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 240947518880.49286
# Fold 1: R2: 0.6123985514428028
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/c1b5fcc172d04e9ca369fe2cd842cee5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 241166319225.8989
# Fold 2: R2: 0.6020169002381005
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/c24d5982d0e5417ebe63e7113b2192b3
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  251584907457.0304
# Validation R2:  0.6033188909675865
# 🏃 View run method-mini-lr-0.001-reg-Ridge-poly-False-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/9e2d82d647364fd9a27ed58135d854d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 275720582454.14526
# Fold 0: R2: 0.590972533836368
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/1659bb2ac6ce481a977b4861cc975a42
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 243250298543.28992
# Fold 1: R2: 0.6086941732564024
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/7b911af473fe45c288e42d78905a7651
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 243759019115.58325
# Fold 2: R2: 0.5977383146455477
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/4137b7dbc2a74101be635153dc0bf38e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  254243300037.67282
# Validation R2:  0.599135007246106
# 🏃 View run method-mini-lr-0.0001-reg-Ridge-poly-False-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/4a07cfbb6baa48b688d4f2df3d1e6dd0
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== xavier =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE 274671560074.6427
# Fold 0: R2: 0.5925287432495998
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/6bad8c490f794502aa11f4609e426ce2
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 238621595740.343
# Fold 1: R2: 0.616140159501452
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/ea0041abb0b34fbab1cf2e84c4388261
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 237638230216.44644
# Fold 2: R2: 0.6078391054478692
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/48a1b896c13c439ea2da9f592e95eee0
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  250310462010.4774
# Validation R2:  0.6055026693996403
# 🏃 View run method-mini-lr-0.01-reg-Ridge-poly-False-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/8a0e1ee90b22419c81de7ee3c0106595
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 272414178382.154
# Fold 0: R2: 0.5958775360949666
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/bf7d644bc58d473eb18da7ca37488921
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 240218585617.7145
# Fold 1: R2: 0.6135711536337992
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/ebaa915128ca448987cbbb652fe577bc
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 240610710412.6256
# Fold 2: R2: 0.6029337899533448
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/5a3ed9d4ad5c40198602c443b740a9d1
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  251081158137.49805
# Validation R2:  0.6041274932273701
# 🏃 View run method-mini-lr-0.001-reg-Ridge-poly-False-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/1d4b76223390424e83ce6c5edb7b7dcc
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 274183086366.50854
# Fold 0: R2: 0.5932533868773888
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/32a4b5b0389945a0b76597bf58578874
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 242012585586.7777
# Fold 1: R2: 0.610685226482728
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/e44e7e39b33b4929a41f3e9c9c954e1e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 243411616613.69394
# Fold 2: R2: 0.5983116132927666
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/6282ec4683db457abc13e4611e3330bc
# ...
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 195909320854.73032
# Fold 0: R2: 0.7093713773784914
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/1e7d43e9b48b4df2ab342d1baea1d40d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 213912490295.73993
# Fold 1: R2: 0.6558885873224951
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/af28fc989aa14d5bb4bb2d19ae96bd5b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 242953904919.0269
# Fold 2: R2: 0.5990669489450482
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/1a850dfe9dc343aeab575b5b78e816c4
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  217591905356.49902
# Validation R2:  0.6547756378820117
# 🏃 View run method-batch-lr-0.001-reg-Normal-poly-True-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/630db15167cd4aebb75f7a27fb8cc61e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 471886894497.2437
# Fold 0: R2: 0.29996266853189035
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/cf30cdb32cf74b519dc5f6b9c2cec2ad
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 424076394844.05444
# Fold 1: R2: 0.3178073561239021
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/b24de489fbd14025b449e118b7bc3b87
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 408100232039.8669
# Fold 2: R2: 0.3265353309611956
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/67df16e6fc604ef6b0998c1f6de9de4b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  434687840460.38837
# Validation R2:  0.3147684518723293
# 🏃 View run method-batch-lr-0.0001-reg-Normal-poly-True-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/159df9a66aec42d68bb2caf20e49c698
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# =====Linear=====
# ===== zero =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE 253958737329.82996
# Fold 0: R2: 0.6232559139562559
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/8ebb375abfc247c59575c67166a8a59a
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 231909930115.0483
# Fold 1: R2: 0.6269369144573976
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/cb18ebe8b7df4aa5a61a293eddab5f06
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 241009900490.43027
# Fold 2: R2: 0.6022750292065339
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/3ca1fc86de4e4403a2331a0ff99a1f03
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  242292855978.4362
# Validation R2:  0.6174892858733957
# 🏃 View run method-batch-lr-0.01-reg-Normal-poly-False-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/e08d9104870d4f8da368db4ccaf9706d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 365420125848.4326
# Fold 0: R2: 0.45790456834742266
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/e7a179631673450593420a872cad554e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 324530590649.22577
# Fold 1: R2: 0.4779422190308905
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/43b960f0653c42a8b345d4b7794e4d16
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 316187060645.6295
# Fold 2: R2: 0.4782144251972409
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/b8cdced5f5ab4491994634fbc4515830
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  335379259047.76263
# Validation R2:  0.47135373752518467
# 🏃 View run method-batch-lr-0.001-reg-Normal-poly-False-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/b0ed9407975641808343d1e1de3d44df
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 915978329507.2582
# Fold 0: R2: -0.3588405038331133
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/e4906abaf0a743b6898cfe02622443df
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 851116986267.5889
# Fold 1: R2: -0.3691536576169403
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/01c811c945704895a4ab1bc2000bf990
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 830570272792.527
# Fold 2: R2: -0.3706430184657319
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/e2cd412d0a144c4eb1560bedb2683908
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  865888529522.458
# Validation R2:  -0.36621239330526184
# 🏃 View run method-batch-lr-0.0001-reg-Normal-poly-False-momentum-Momentum Used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/ed896441cfc44936bd13dde0dd5bfdba
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Momentum not used =====
# ===== 0.01 =====
# Fold 0: MSE 255684071666.11185
# Fold 0: R2: 0.6206964056106218
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/d9a43b64300a4dd0b508cb484598c2a7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 232464528023.74402
# Fold 1: R2: 0.6260447577181375
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/2271dfc6bed242f98d16778e7ad5e615
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 244110274510.13614
# Fold 2: R2: 0.5971586577880688
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/c037961261ec4a1080fffdce4d8a25de
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  244086291399.9973
# Validation R2:  0.6146332737056094
# 🏃 View run method-batch-lr-0.01-reg-Normal-poly-False-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/8cb6aab05b6b4b54b4d4ffd3ff4c1e0d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 534586130260.825
# Fold 0: R2: 0.20694926595415963
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/a3ef826221e54fe5925dd29852e5e1ec
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 481273120413.5414
# Fold 1: R2: 0.22579755338151553
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/26eb10aa1d9a4308933ce9fe486505c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 465608196054.71875
# Fold 2: R2: 0.2316331992991526
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/6ba0d40804f44db5b0f5d3c7c6132344
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  493822482243.0284
# Validation R2:  0.22146000621160924
# 🏃 View run method-batch-lr-0.001-reg-Normal-poly-False-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/6ccb7dca293f4186a3dd84680c3366f0
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 999808154462.3174
# Fold 0: R2: -0.48320082755327354
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/c79c1d3a286040739d88e39d163c0b0e
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 933626921902.216
# Fold 1: R2: -0.5018836841427778
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/bd46c059a4c845bfa8480dddb704c705
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 912592757561.7866
# Fold 2: R2: -0.506000073478319
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/fb51214cd8ed4af3afa32247bfa051ee
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  948675944642.1066
# Validation R2:  -0.49702819505812346
# 🏃 View run method-batch-lr-0.0001-reg-Normal-poly-False-momentum-Momentum not used-init-zero at: http://localhost:5000/#/experiments/190877290999588017/runs/a176ebbd53674faf8c6eb612e931ae32
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== xavier =====
# ===== Momentum Used =====
# ===== 0.01 =====
# Fold 0: MSE 253958736092.34064
# Fold 0: R2: 0.6232559157920534
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/43c23b6013574025876c9df31e0e3080
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 231909932896.09485
# Fold 1: R2: 0.626936909983653
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/fcc7bceecab3416bb27df90edd813853
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 241009887830.67297
# Fold 2: R2: 0.6022750500982134
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/f24fdfe6148841c0aaeb3e0f941aa3d1
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  242292852273.03613
# Validation R2:  0.6174892919579733
# 🏃 View run method-batch-lr-0.01-reg-Normal-poly-False-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/d601c4d998014dbab17048765fd2a9b9
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 365419870961.06433
# Fold 0: R2: 0.45790494646911917
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/696edcfbb8a34d41bdf1dd5f10c9b399
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 324530350781.14716
# Fold 1: R2: 0.477942604895892
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/0096ab7e573f498ca4d772d489b4a438
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 316187381608.4743
# Fold 2: R2: 0.47821389553046045
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/b90dfc6095cf47fd936a969b7cbdade9
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  335379201116.89526
# Validation R2:  0.4713538156318238
# 🏃 View run method-batch-lr-0.001-reg-Normal-poly-False-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/e42cc43b17a14859907354d5c97dfe91
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 915978797598.4084
# Fold 0: R2: -0.35884119823951344
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/96d5a7436c4b4b23a7cec4f8491875ec
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 851116193442.8567
# Fold 1: R2: -0.3691523822354128
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/14c2a70c5260486e836dbf5b6f564843
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 830568911893.8038
# Fold 2: R2: -0.37064077265174733
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/d5dad094ee88442fb960a86c779d9efe
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  865887967645.023
# Validation R2:  -0.3662114510422245
# 🏃 View run method-batch-lr-0.0001-reg-Normal-poly-False-momentum-Momentum Used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/791d023505f04bbbbc8b5a6876608c4b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== Momentum not used =====
# ===== 0.01 =====
# Fold 0: MSE 255684081070.0008
# Fold 0: R2: 0.6206963916600896
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/bfa3d84fcc554c90a5436637c943bb64
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 232464531377.11108
# Fold 1: R2: 0.6260447523237265
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/c1bf70a4b35440e09a175f840d6d0b31
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 244110266854.61914
# Fold 2: R2: 0.5971586704215344
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/72c133823b3c462fb9beb424cc7adce8
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  244086293100.577
# Validation R2:  0.6146332714684501
# 🏃 View run method-batch-lr-0.01-reg-Normal-poly-False-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/422ec2a1bbc34017aeeb7516e2c9ef17
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.001 =====
# Fold 0: MSE 534585796256.4115
# Fold 0: R2: 0.20694976144483979
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/f4c298df9d2a415a8aa9306b9243ff38
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 481273366881.6986
# Fold 1: R2: 0.22579715689926416
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/d85dceee889f4fe58f67c29ac9e0528b
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 465608241981.6387
# Fold 2: R2: 0.23163312350856124
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/442fa7befe49467b9e89707b6602e1bd
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  493822468373.2496
# Validation R2:  0.2214600139508884
# 🏃 View run method-batch-lr-0.001-reg-Normal-poly-False-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/0b2c796f75f148919130f9419a0e6be8
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# ===== 0.0001 =====
# Fold 0: MSE 999807253229.2845
# Fold 0: R2: -0.4831994905872026
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/ef3a5716765540c5b1bfa0a45c94cd1f
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 933628031926.3945
# Fold 1: R2: -0.5018854697888038
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/34f58aa43d004925bd5e591303d76a93
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 912591165598.1394
# Fold 2: R2: -0.5059974463509942
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/6f83d66322314ce4bfd9fcf855a65d62
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Validation MSE:  948675483584.6061
# Validation R2:  -0.4970274689090002
# 🏃 View run method-batch-lr-0.0001-reg-Normal-poly-False-momentum-Momentum not used-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/fa6e72c944b94915a9dae29ed4b13c7d
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017

# %%
# Testing
reg = "Normal"
ispoly= False
methods=["batch"]
momentum = True
# Only testing diff initialization here
inits=["xavier"]
for method in methods:
    for init in inits:
        params = {"method": method,"polynomial": ispoly,  "lr": 0.01, "l": 0.1, "init" :init, 
        "degree":2, "use_momentum" :momentum,  "momentum":0.9}
        mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{ispoly}-momentum-{momentum}-init-{init}", nested=True)
        
        print("="*5, reg, "="*5)
        print("Method: ", method)
        print("Momentum: ", momentum)
        print("Inititalization: ", init)
        print("Learning Rate: ", "0.01")
        print("="*10)
        
        type_of_regression = str_to_class(reg)    
        model = type_of_regression(**params)  
        model.fit(X_train, y_train)
        yhat = model.predict(X_test)
        mse  = model.mse(yhat, y_test)
        r2 = model.r2(yhat, y_test)
        
        print("Test MSE: ", mse)
        print("Test R2: ", r2)
        mlflow.log_metric(key="test_mse", value=mse)
        mlflow.log_metric(key="test_r2", value=r2)
        signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
        mlflow.sklearn.log_model(model, name='model', signature=signature)

        mlflow.end_run()
# Out:
# ===== Normal =====
# Method:  batch
# Momentum:  True
# Inititalization:  xavier
# Learning Rate:  0.01
# ==========
# Fold 0: MSE 262435910633.60608
# Fold 0: R2: 0.610680150892756
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/190877290999588017/runs/d8f8ce7c822d47c5a2b2cdf87fc3e768
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 1: MSE 230871926906.6038
# Fold 1: R2: 0.6286067035843804
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/190877290999588017/runs/857a588cd0bf4afd86e0186069888005
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Fold 2: MSE 239513763001.08707
# Fold 2: R2: 0.604744020057288
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/190877290999588017/runs/774030355ad549f1914fdf930aac47ca
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017
# Test MSE:  237737718475.00696
# Test R2:  0.4176115836098462
# 🏃 View run method-batch-lr-0.01-reg-Normal-poly-False-momentum-True-init-xavier at: http://localhost:5000/#/experiments/190877290999588017/runs/239c610d3429464fa9bfc0b2231d4419
# 🧪 View experiment at: http://localhost:5000/#/experiments/190877290999588017

# %%
pd.options.display.float_format = '{:.2f}'.format  # Set to 2 decimal places

pd.DataFrame({'Actual Price:': np.exp(y_test), 'Predicted Price:': np.exp(yhat)})
# Out:
#       Actual Price:  Predicted Price:
# 5948            inf               inf
# 6039            inf               inf
# 3069            inf               inf
# 6531            inf               inf
# 322             inf               inf
# ...             ...               ...
# 5744            inf               inf
# 1010            inf               inf
# 4856            inf               inf
# 7542            inf               inf
# 560             inf               inf
#
# [2409 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))

# Scatterplot of actual vs predicted
sns.scatterplot(x=y_test, y=yhat, alpha=0.7, label='Predicted')

# Plot reference line y = x
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         color='red', label='Ideal Fit')

plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.show()

# %%
residuals = y_test - yhat

plt.figure(figsize=(12,3))
sns.histplot(residuals, bins=30, kde=True)
plt.title("Residual Distribution of Linear Regression Predictions")
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.axvline(0, color='red', linestyle='dashed')
plt.show()

# %%
fi = model.feature_importance(width=12, height=5)  # Display feature importance
print(fi)
# Out:
# None

# %%
from sklearn.inspection import permutation_importance


# permutation importance
perm_imp = permutation_importance(
    model,            # our model needs to have predict() method
    X_test,
    y_test.values if isinstance(y_test, pd.Series) else y_test,
    n_repeats=10,
    random_state=42,
    scoring='r2'
)

# Create a DataFrame for visualization
perm_df = pd.DataFrame({
    'Feature': model.columns,
    'Importance_Mean': perm_imp.importances_mean,
    'Importance_STD': perm_imp.importances_std
}).sort_values(by='Importance_Mean', ascending=True)

# Plot using bar 
perm_df.plot(kind='bar', x='Feature', y='Importance_Mean', figsize=(12,5), xerr='Importance_STD', legend=True)
plt.title("Permutation Feature Importance")
plt.xlabel("Mean decrease in R²")
plt.show()

# %%
import shap

# create an explainer for linear model
explainer = shap.Explainer(model.predict, X_test if isinstance(X_test, pd.DataFrame) else pd.DataFrame(X_test, columns=model.columns))

# calculate SHAP values
shap_values = explainer(X_test)

# summary plot
shap.summary_plot(shap_values, X_test if isinstance(X_test, pd.DataFrame) else pd.DataFrame(X_test, columns=model.columns))

# %%
import joblib
# Save the model to a file
joblib.dump(model, '../app/model/a2_model.pkl')
joblib.dump(scaler, '../app/model/a2_scaler.pkl')
# Out:
# ['../app/model/a2_scaler.pkl']

# %%
# loading saved models
loaded_model = joblib.load('../app/model/a2_model.pkl')
loaded_scaler = joblib.load('../app/model/a2_scaler.pkl')

# %%
df.iloc[1]
# Out:
# brand            27.00
# sell_price   370000.00
# km           120000.00
# fuel              0.00
# sell_type         1.00
# mileage          21.14
# engine         1498.00
# max_power       103.52
# seats             5.00
# Name: 1, dtype: float64

# %%
df[['brand', 'km', 'fuel', 'sell_type', 'mileage', 'engine', 'seats','max_power']].loc[1]
# Out:
# brand           27.00
# km          120000.00
# fuel             0.00
# sell_type        1.00
# mileage         21.14
# engine        1498.00
# seats            5.00
# max_power      103.52
# Name: 1, dtype: float64

# %%
sample = np.array([[27,120000,0,1,21.14,1498,5,103.52]])

# %%
predicted_Car_Price = loaded_model.predict(sample)
predicted_Car_Price
# Out:
# array([-2.07e+10])

# %%
sample = loaded_scaler.transform(sample)
sample
# Out:
# array([[ 1.23,  0.83, -0.91,  0.29,  0.44,  0.08, -0.43,  0.33]])

# %%
predicted_car_price = loaded_model.predict(sample)
np.set_printoptions(precision=2)
print("Predicted Price: ", str(np.exp(predicted_car_price)))
# Out:
# Predicted Price:  [inf]
